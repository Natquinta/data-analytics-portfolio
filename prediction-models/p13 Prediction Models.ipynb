# %% [markdown]
# Hola **Natalia**!
#
# Soy **Patricio Requena** 👋. Es un placer ser el revisor de tu proyecto el día de hoy!
#
# Revisaré tu proyecto detenidamente con el objetivo de ayudarte a mejorar y perfeccionar tus habilidades. Durante mi revisión, identificaré áreas donde puedas hacer mejoras en tu código, señalando específicamente qué y cómo podrías ajustar para optimizar el rendimiento y la claridad de tu proyecto. Además, es importante para mí destacar los aspectos que has manejado excepcionalmente bien. Reconocer tus fortalezas te ayudará a entender qué técnicas y métodos están funcionando a tu favor y cómo puedes aplicarlos en futuras tareas.
#
# _**Recuerda que al final de este notebook encontrarás un comentario general de mi parte**_, empecemos!
#
# Encontrarás mis comentarios dentro de cajas verdes, amarillas o rojas, ⚠️ **por favor, no muevas, modifiques o borres mis comentarios** ⚠️:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si todo está perfecto.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si tu código está bien pero se puede mejorar o hay algún detalle que le hace falta.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si de pronto hace falta algo o existe algún problema con tu código o conclusiones.
# </div>
#
# Puedes responderme de esta forma:
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class=“tocSkip”></a>
# </div>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introducción" data-toc-modified-id="Introducción-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introducción</a></span><ul class="toc-item"><li><span><a href="#Objetivos" data-toc-modified-id="Objetivos-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Objetivos</a></span></li></ul></li><li><span><a href="#Análisis-exploratorio-de-datos" data-toc-modified-id="Análisis-exploratorio-de-datos-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Análisis exploratorio de datos</a></span><ul class="toc-item"><li><span><a href="#Corrección-de-datos" data-toc-modified-id="Corrección-de-datos-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Corrección de datos</a></span></li><li><span><a href="#Análisis-comparativo-entre-clientes-que-se-quedaron-y-los-que-cancelaron." data-toc-modified-id="Análisis-comparativo-entre-clientes-que-se-quedaron-y-los-que-cancelaron.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Análisis comparativo entre clientes que se quedaron y los que cancelaron.</a></span></li></ul></li><li><span><a href="#Construcción-de-un-modelo-para-predecir-la-cancelación-de-usuarios" data-toc-modified-id="Construcción-de-un-modelo-para-predecir-la-cancelación-de-usuarios-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Construcción de un modelo para predecir la cancelación de usuarios</a></span><ul class="toc-item"><li><span><a href="#Modelo-regresión-logistica" data-toc-modified-id="Modelo-regresión-logistica-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Modelo regresión logistica</a></span></li><li><span><a href="#Modelo-Bosque-Aleatorio" data-toc-modified-id="Modelo-Bosque-Aleatorio-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Modelo Bosque Aleatorio</a></span></li><li><span><a href="#Comparación-de-modelos" data-toc-modified-id="Comparación-de-modelos-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Comparación de modelos</a></span></li></ul></li><li><span><a href="#Crear-clústers-de-usuarios" data-toc-modified-id="Crear-clústers-de-usuarios-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Crear clústers de usuarios</a></span></li><li><span><a href="#Conclusiones-y-recomendaciones" data-toc-modified-id="Conclusiones-y-recomendaciones-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Conclusiones y recomendaciones</a></span><ul class="toc-item"><li><span><a href="#Conclusiones-a-partir-de-las-visualizaciones" data-toc-modified-id="Conclusiones-a-partir-de-las-visualizaciones-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Conclusiones a partir de las visualizaciones</a></span></li><li><span><a href="#Conclusiones-generales" data-toc-modified-id="Conclusiones-generales-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Conclusiones generales</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Proyecto Sprint 13: Pronósticos y predicciones

# %% [markdown]
# ## Introducción

# %% [markdown]
# En este proyecto se busca desarrollar una estrategia basada en datos para reducir la pérdida de clientes y predecirla, un fenómeno común para los gimnasios. El análisis a produndiad de los factores que contribuyen a la cancelación de membresias es la base para crear medidas de retención más efectivas.Este proyecto tiene como objetivo analizar los perfiles de los clientes de Model Fitness, identificar los factores que afectan la cancelación y desarrollar estrategias basadas en estos análisis para mejorar la relación con los clientes y reducir la tasa de cancelación.

# %% [markdown]
# ### Objetivos

# %% [markdown]
# - Predecir la probabilidad de pérdida de clientes: Desarrollar un modelo de predicción que identifique a los clientes con alta probabilidad de cancelar su membresía en el próximo mes.
#
# - Segmentar a los clientes: Crear perfiles de clientes basados en sus características y comportamientos, con el fin de entender mejor sus necesidades y patrones de cancelación.
#
# - Analizar los factores que impactan la pérdida: Identificar las variables más importantes que contribuyen a la cancelación de clientes, como frecuencia de visitas, duración del contrato, y gastos adicionales.
#
# - Proponer recomendaciones de retención: Sugerir estrategias específicas para reducir las cancelaciones, dirigidas a los segmentos más vulnerables y optimizar la experiencia de los clientes.
#
# - Visualizar patrones y conclusiones: Utilizar visualizaciones para presentar los hallazgos clave y ofrecer recomendaciones claras para mejorar la interacción con los clientes.

# %% [markdown]
# ## Análisis exploratorio de datos

# %%
#Importación de librerias
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import linkage, dendrogram
from sklearn.cluster import KMeans

# %%
#Cargar los datos
df = pd.read_csv('/datasets/gym_churn_us.csv')

# %%
#Información de los datasets
df.info()
print()
display(df.describe())
print()
display(df. head())
print()
#Duplicados
print("Duplicados en Data: ", df.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             4000 non-null   int64
#  1   Near_Location                      4000 non-null   int64
#  2   Partner                            4000 non-null   int64
#  3   Promo_friends                      4000 non-null   int64
#  4   Phone                              4000 non-null   int64
#  5   Contract_period                    4000 non-null   int64
#  6   Group_visits                       4000 non-null   int64
#  7   Age                                4000 non-null   int64
#  8   Avg_additional_charges_total       4000 non-null   float64
#  9   Month_to_end_contract              4000 non-null   float64
#  10  Lifetime                           4000 non-null   int64
# ...

# %% [markdown]
# ### Corrección de datos

# %%
#nombres de las columnas
df.columns = df.columns.str.lower()
display(df.head())
# Out:
#    gender  near_location  partner  promo_friends  phone  contract_period  \
# 0       1              1        1              1      0                6
# 1       0              1        0              0      1               12
# 2       0              1        1              0      1                1
# 3       0              1        1              1      1               12
# 4       1              1        1              1      1                1
#
#    group_visits  age  avg_additional_charges_total  month_to_end_contract  \
# 0             1   29                     14.227470                    5.0
# 1             1   31                    113.202938                   12.0
# 2             0   28                    129.448479                    1.0
# 3             1   33                     62.669863                   12.0
# 4             0   26                    198.362265                    1.0
#
#    lifetime  avg_class_frequency_total  avg_class_frequency_current_month  \
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# Bien hecha la exploración inicial de tus datos, siempre hay que entender con que se está trabajando
# </div>

# %% [markdown]
# ### Análisis comparativo entre clientes que se quedaron y los que cancelaron.

# %%
churn_comparison = df.groupby('churn').mean()
display(churn_comparison)
# Out:
#          gender  near_location   partner  promo_friends     phone  \
# churn
# 0      0.510037       0.873086  0.534195       0.353522  0.903709
# 1      0.510839       0.768143  0.355325       0.183789  0.902922
#
#        contract_period  group_visits        age  avg_additional_charges_total  \
# churn
# 0             5.747193      0.464103  29.976523                    158.445715
# 1             1.728558      0.268615  26.989632                    115.082899
#
#        month_to_end_contract  lifetime  avg_class_frequency_total  \
# churn
# 0                   5.283089  4.711807                   2.024876
# 1                   1.662582  0.990575                   1.474995
#
#        avg_class_frequency_current_month
# churn
# 0                               2.027882
# 1                               1.044546

# %% [markdown]
# Se agruparon los datos por 'churn', para saber si los clientes tienen diferencias entre las medias de las características. Las características que presentan más diferencias son: 'promo_friends', que nos indica que las personas que se quedan normalmente utilizaron un codigo de referencia de otro cliente, 'contract_period' nos indica que las personas que se quedan tienen un contrato más largo, 'group_visits' indica que los clientes que se quedan tienden a participar más en clases grupales, y asisten a clases con más frecuencia.

# %%
# Definir las características a graficar
features = ['lifetime', 'avg_class_frequency_total', 'contract_period', 'avg_additional_charges_total']

# Crear un gráfico para cada característica
plt.figure(figsize=(12, 8))
for i, feature in enumerate(features, 1):
    plt.subplot(2, 2, i) 
    sns.histplot(df[df['churn'] == 0][feature], kde=True, color='blue', label='Se quedó', bins=20)  # Clientes que se quedaron
    sns.histplot(df[df['churn'] == 1][feature], kde=True, color='red', label='Canceló', bins=20)  # Clientes que cancelaron
    plt.title(f'Distribución de {feature}')
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# Muy bien hecho! Estas gráficas son muy claras para mostrar las diferencias entre cada variable de tu dataset, además el redactar conclusiones tan claras de las mismas ayuda mucho a seguir el proceso de análisis
# </div>

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(df.corr(), annot=True, fmt=".2f",cmap="coolwarm", linewidths=0.5)
plt.title("Matriz de correlación")
plt.show()

# %% [markdown]
# En los gráficos anteriores podemos ver las distribuciones de las características. Se puede observar que los clientes que cancelan tienen un lifetime mucho más corto que los que se quedan. En cuanto a duración de contrato, la gente con contratos cortos tiene mayor indice de cancelación que la que tiene contratos largos (1 mes vs 12 meses). Los clientes que se quedan tienen una asistencia mucho mayor a clases (avg_class_frequency_total) que aquellos que cancelan, y también tienen más cargos adicionales.
#
# En el mapa de calor de correlaciones se observa que la correlación más fuerte es la de clases en promedio al mes vs en total.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# Muy bien mostrada la matriz de correlación! Solo ten en cuenta que no siempre correlación significa causalidad, puede que en algunos casos tengas variables altamente correlacionadas pero no necesariamente son causa una de la otra

# %% [markdown]
# ## Construcción de un modelo para predecir la cancelación de usuarios

# %% [markdown]
# Aquí vamos a crear un modelo de clasificación binaria para predecir si un cliente cancelará o no en el próximo mes. Se utilizarán 2 modelos: el de regresión logística y el de bosque aleatorio, para comparar los resultados y concluir qué modelo dará mejores resultados

# %%
# Definir las características y la variable objetivo 
X = df.drop('churn', axis=1) 
y = df['churn'] 

# Dividir los datos en entrenamiento y validación (80/20)
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# ### Modelo regresión logistica

# %%
# Crear el modelo de regresión logística
log_model = LogisticRegression(max_iter=1000)

# Entrenar el modelo
log_model.fit(X_train, y_train)

# Realizar predicciones
y_pred_log = log_model.predict(X_valid)

# Evaluar el modelo
print(f'Modelo:{log_model}')
print(f'Exactitud: {accuracy_score(y_valid, y_pred_log)}')
print(f'Precisión: {precision_score(y_valid, y_pred_log)}')
print(f'Recall: {recall_score(y_valid, y_pred_log)}')
# Out:
# Modelo:LogisticRegression(max_iter=1000)
# Exactitud: 0.93625
# Precisión: 0.8979591836734694
# Recall: 0.8502415458937198

# %% [markdown]
# La exactitud del modelo predijo correctamente el 93.75% de las veces. En este caso, el modelo tiene una precisión del 87.38%, lo que significa que de todas las predicciones de cancelación, aproximadamente el 87.38% fueron correctas. Un recall de 0.89 significa que el modelo identificó correctamente al 89% de los clientes que cancelaron.
#
# Las metricas de este modelo muestran que funciona bien, sin embargo hay que compararlo con el modelo de Random Forrest para detectar el de mejor desempeño.

# %% [markdown]
# ### Modelo Bosque Aleatorio

# %%
# Crear el modelo de bosque aleatorio
rf_model = RandomForestClassifier()

# Entrenar el modelo
rf_model.fit(X_train, y_train)

# Realizar predicciones
y_pred_rf = rf_model.predict(X_valid)

# Evaluar el modelo
print(f'Modelo:{rf_model}')
print(f'Exactitud: {accuracy_score(y_valid, y_pred_rf)}')
print(f'Precisión: {precision_score(y_valid, y_pred_rf)}')
print(f'Recall: {recall_score(y_valid, y_pred_rf)}')
# Out:
# Modelo:RandomForestClassifier()
# Exactitud: 0.93375
# Precisión: 0.9010416666666666
# Recall: 0.8357487922705314

# %% [markdown]
# El modelo de bosque aleatorio tiene una exactitud de 92.13%, lo que indica que es muy efectivo en términos generales, aunque es menor al de regresión logística. La precisión es muy similar a la de la regresión logística, sin embargo el recall es más bajo que en el modelo de regresión logística, lo que sugiere que este modelo presenta más falsos positivos.

# %% [markdown]
# ### Comparación de modelos

# %% [markdown]
# El modelo de regresión logística tiene un mejor desempeño en términos de recall, lo cual es clave para detectar correctamente a los clientes que van a cancelar, mientras que el modelo de bosque aleatorio tiene una mayor precisión y un recall ligeramente menor, lo que significa que es más preciso cuando predice que un cliente cancelará, pero pierde más clientes potenciales que realmente cancelan.
#
# Ambos modelos pueden funcionar dependiendo del objetivo, para minimizar la pérdida de clientes (identificar a los clientes que probablemente van a cancelar), la regresión sería la mejor opcion, ya que tiene un recall más alto.
# Por otro lado, para predecir correctamente a los clientes que cancelan y mantener una buena precisión, entonces el modelo de bosque sería la mejor opción.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# Muy buen trabajo! Obtuviste resultados muy buenos en el entrenamiento de tus modelos y realizaste el análisis adecuado a partir de los mismos
#
# </div>

# %% [markdown]
# ## Crear clústers de usuarios

# %% [markdown]
# El objetivo de este paso es segmentar a los usuarios en diferentes grupos para analizar sus comportamientos y características. Se llevará a cabo la segmentación con el algoritmo de KMeans. Primero se deben estandarizar los datos y después crear una matriz para aplicarle el algoritmo y lograr segmentar a los clientes.

# %%
#Estandarizar los datos
features_to_cluster = ['age', 'lifetime', 'avg_class_frequency_total', 'avg_class_frequency_current_month', 'avg_additional_charges_total']
X = df[features_to_cluster].dropna()  # Elimina valores faltantes

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# Usamos StandardScaler para normalizar las características seleccionadas para que tengan una media de 0 y una desviación estándar de 1. Esto asegura que las características no sesguen el clustering.

# %%
#Crear el dendrograma
linked = linkage(X_scaled, method='ward')  # Calcular la matriz de distancias

plt.figure(figsize=(10, 7))
dendrogram(linked)

# Línea de corte: Puedes ajustar la altura de corte según lo que necesites
plt.axhline(y=45, color='r', linestyle='--')  # La línea de corte roja a la altura 30 (ajustar según tus necesidades)

plt.title('Dendrograma de Clústeres')
plt.xlabel('Índice de Clientes')
plt.ylabel('Distancia')
plt.show()

# %% [markdown]
# La función linkage() genera la matriz de distancias entre los puntos (clientes), y con dendrogram() la visualizamos. Esto nos ayuda a decidir cuántos clústeres usar en el siguiente paso. Se traazó una línea de corte para contar los clústeres, y se decidió que se agruparán en 5 clusters.

# %%
# Aplicar K-Means decidimos que el número de clústeres es 5
kmeans = KMeans(n_clusters=5, random_state=42)
df['cluster'] = kmeans.fit_predict(X_scaled)

# %% [markdown]
# El algoritmo de K-Means segmenta los clientes en 5 clústeres, después de aplicar el algoritmo, asignamos a cada cliente un clúster usando kmeans.fit_predict()

# %%
# Analizar los clústeres y ver las características promedio de cada clúster
cluster_means = df.groupby('cluster')[features_to_cluster].mean()
display(cluster_means)
# Out:
#                age   lifetime  avg_class_frequency_total  \
# cluster
# 0        25.843007   1.617507                   1.347839
# 1        30.121665   3.431163                   2.895957
# 2        29.719888  12.515406                   2.009427
# 3        31.171859   3.136683                   1.041390
# 4        29.887879   3.628788                   2.473394
#
#          avg_class_frequency_current_month  avg_additional_charges_total
# cluster
# 0                                 1.036828                    108.878849
# 1                                 2.879782                     94.610599
# 2                                 2.014015                    142.377943
# 3                                 0.941106                    154.192599
# 4                                 2.461729                    273.397800

# %% [markdown]
# En esta tabla podemos ver las características promedio de cada grupo, podemos ver que el grupo 2 tiene un lifetime de aprox 12 meses, mientras que el grupo 0 tiene un lifetime de a penas 1 mes. Estas características nos ayudan a entender cómo están agrupados los datos. A continuación se muestran las visualizaciones para las distintas características.

# %%
# Visualización: distribuciones de características para cada clúster
for feature in features_to_cluster:
    plt.figure(figsize=(6, 4))
    sns.histplot(data=df, x=feature, hue='cluster', multiple="stack", kde=True)
    plt.title(f'Distribución de {feature} por Clúster')
    plt.show()

# %%
# Analizar la tasa de cancelación por clúster
churn_rate_by_cluster = df.groupby('cluster')['churn'].mean()
print(churn_rate_by_cluster)
# Out:
# cluster
# 0    0.679353
# 1    0.092850
# 2    0.002801
# 3    0.214070
# 4    0.069697
# Name: churn, dtype: float64

# %% [markdown]
# Se analiza la media de las características en cada clúster y se observan distribuciones para entender mejor cómo se agrupan los usuarios. También calculamos la tasa de cancelación por clúster para entender la propensidad de cancelación de cada grupo, se puede observar que el cluster 0 tiene mayor propensidad a cancelar.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# Bien hecho! Se nota claramente la segmentación entre los diferentes grupos ya que tienen un churn rate diferente
#
# </div>

# %% [markdown]
# ## Conclusiones y recomendaciones

# %% [markdown]
# ### Conclusiones a partir de las visualizaciones

# %% [markdown]
# 1. Distribución de edad
#     La mayoría de los clientes tienen entre 25 y 35 años. No hay muchos clientes fuera de este rango.
#     El cluster 0 es el más numeroso y tiene un promedio de edad de 25.8 años.
#     Puede ser útil diseñar estrategias específicas para atraer y retener a clientes de la edad del cluster 0, especialmente por que hay diferencias en su tasa de cancelación.
#
# 2. Distribución de lifetime
#     La mayoria de los clientes tienen un lifetime corto, menor a 6 meses.
#     La cantidad de clientes disminuye a medida que aumenta el lifetime, con muy pocos clientes superando los 10 meses de permanencia.
#     El cluster 0 tiene el lifetime más corto y es el más numeroso, mientras que los clusters 3 y 4 son menos en cantidad pero tienen un lifetime más prolongado.
#     El gráfico sugiere que se pueden hacer estrategias para prolongar la permanencia de los clientes, sobre todo en los primeros 6 meses.
#
# 3. Distribución de clases en promedio total
#     La mayoría de los clientes van en promedio a 1-3 clases por semana, aunque tenemos un grupo pequeño que no asiste a clases.
#     Los clusters con mayor asistencia son el 3 y 4, con un promedio de 2-3 clases por semana. Es importante recordar que este mismo grupo es el que tiene un lifetime más largo, por lo que se puede crear una estrategia para incentivar a que los clientex de los otros grupos asistan a más clases.
#
# 4. Distribucion de clases en promedio mensual
#     Se observan las mismas tendencias que en la distribución anterior, ya que estan fuertemente relacionadas.
#     El cluster 0 tiene un grupo de clientes que no asisten a clases.
#     El cluster 4 parece ser el más comprometido con las clases.
#
# 5. Distribución de Cargos adicionales al mes
#     Se observa que el cluster 4 tiene más cargos adicionales al mes que el resto de los grupos.
#     La mayor parte de los clientes no tiene cargos adicionales por más de 200 al mes.

# %% [markdown]
# ### Conclusiones generales

# %% [markdown]
# El análisis de clustering reveló cinco grupos de clientes en función de características clave como edad, tiempo de permanencia en el gimnasio (lifetime) y frecuencia de asistencia a clases.
# La mayoría de los clientes tienen entre 25 y 35 años, con una ligera variación entre clusters. La mayor parte de los clientes permanecen en el gimnasio por menos de 5 meses, lo que indica una posible oportunidad de mejorar la retención. Existe una correlación positiva entre la asistencia a clases y el tiempo de permanencia, sugiriendo que los clientes más activos tienden a quedarse más tiempo. Algunos grupos (clusters 3 y 4) muestran una mayor asistencia a clases y una permanencia más larga, lo que sugiere que este tipo de comportamiento es clave para la retención.

# %% [markdown]
# Como estrategias para aumentar la retencion de clientes, basándonos en los datos analizados previamente se puede sugerir implementar un sistema de recompensas basado en la asistencia frecuente a clases u ofrecer descuentos o beneficios para clientes que superen ciertos meses de permanencia.
# También podría ser recomendable el uso de recomendaciones personalizadas según el cluster al que pertenece cada cliente y promocionar clases específicas que fomenten la fidelidad entre los grupos con menor asistencia.
# Un problema que se identificó fue el churn en los primeros meses, para evitar esto se podría implementar el identificar clientes en clusters con baja frecuencia de clases y enviarles recordatorios o promociones para incentivarlos a participar más.
# Otra estrategia para mejorar la experiencia del cliente podría ser ofrecer planes de acompañamiento o entrenamientos guiados y personalizados y mejorar la oferta de clases en horarios y formatos que se ajusten a las preferencias de los clientes más comprometidos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario general (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# Muy buen trabajo, manejaste muy bien los datos previo al entrenamiento de tus modelos y analizaste muy bien los resultados.
#
# Te felicito por las conclusiones planteadas luego de ver los resultados de la segmentación utilizando los cluster, un buen análisis siempre debe venir acompañado de recomendaciones que ayuden a la toma de decisiones que en este caso haz planteado sugerencias muy buenas en cuanto a los diferentes tipos de usuarios obtenidos.
#
#
# Saludos!
# </div>
