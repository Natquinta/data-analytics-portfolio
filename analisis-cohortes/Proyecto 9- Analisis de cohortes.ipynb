# %% [markdown]
# Hola **Natalia**!
#
# Soy **Patricio Requena** 👋. Es un placer ser el revisor de tu proyecto el día de hoy!
#
# Revisaré tu proyecto detenidamente con el objetivo de ayudarte a mejorar y perfeccionar tus habilidades. Durante mi revisión, identificaré áreas donde puedas hacer mejoras en tu código, señalando específicamente qué y cómo podrías ajustar para optimizar el rendimiento y la claridad de tu proyecto. Además, es importante para mí destacar los aspectos que has manejado excepcionalmente bien. Reconocer tus fortalezas te ayudará a entender qué técnicas y métodos están funcionando a tu favor y cómo puedes aplicarlos en futuras tareas.
#
# _**Recuerda que al final de este notebook encontrarás un comentario general de mi parte**_, empecemos!
#
# Encontrarás mis comentarios dentro de cajas verdes, amarillas o rojas, ⚠️ **por favor, no muevas, modifiques o borres mis comentarios** ⚠️:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si todo está perfecto.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si tu código está bien pero se puede mejorar o hay algún detalle que le hace falta.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si de pronto hace falta algo o existe algún problema con tu código o conclusiones.
# </div>
#
# Puedes responderme de esta forma:
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class=“tocSkip”></a>
# </div>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introducción" data-toc-modified-id="Introducción-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introducción</a></span><ul class="toc-item"><li><span><a href="#Objetivos" data-toc-modified-id="Objetivos-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Objetivos</a></span></li></ul></li><li><span><a href="#Exploración-y-corrección-de-datos" data-toc-modified-id="Exploración-y-corrección-de-datos-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Exploración y corrección de datos</a></span><ul class="toc-item"><li><span><a href="#Exploración" data-toc-modified-id="Exploración-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Exploración</a></span></li><li><span><a href="#Corrección" data-toc-modified-id="Corrección-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Corrección</a></span></li></ul></li><li><span><a href="#Informes-y-cálculo-de-métricas" data-toc-modified-id="Informes-y-cálculo-de-métricas-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Informes y cálculo de métricas</a></span><ul class="toc-item"><li><span><a href="#Visitas" data-toc-modified-id="Visitas-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Visitas</a></span></li><li><span><a href="#Ventas" data-toc-modified-id="Ventas-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Ventas</a></span></li><li><span><a href="#Marketing" data-toc-modified-id="Marketing-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Marketing</a></span></li></ul></li><li><span><a href="#Conclusión" data-toc-modified-id="Conclusión-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Conclusión</a></span></li></ul></div>

# %% [markdown]
# # Proyecto Sprint 9: Análisis de Negocio

# %% [markdown]
# ## Introducción
#
# En este proyecto se pondrán en práctica las habilidades aprendidas durante el sprint 9 de análisis de negocios. Se explorarán los registros de visitas y ventas de la empresa Showz de 2017-2018 con la finalidad de obtener insights que ayuden a comprender el comportamiento de los clientes y optimizar los gastos de marketing en función de las ventas y márgenes de utilidad.

# %% [markdown]
# ### Objetivos
#
# - Describir cómo los clientes utilizan el servicio y cuándo comienzan a hacer compras.
# - Describir el comportamiento de los clientes y el ingreso que traen a la empresa.
# - Analizar el costo de adquisición de los clientes y los ingresos que justifican el mismo.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# Excelente! Redactar la introducción a los proyectos ayuda a la comprensión del mismo
#
# </div>

# %% [markdown]
# ## Exploración y corrección de datos

# %% [markdown]
# ### Exploración

# %%
#Importar libererías
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns
import numpy as np

# %%
#Lectura de datos

visits = pd.read_csv('/datasets/visits_log_us.csv')
orders = pd.read_csv('/datasets/orders_log_us.csv') 
costs = pd.read_csv('/datasets/costs_us.csv')

# %%
#Información sobre los datos

visits.info()
print()
display(visits.describe())
print()
display(visits.head()
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359400 entries, 0 to 359399
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Device     359400 non-null  object
#  1   End Ts     359400 non-null  object
#  2   Source Id  359400 non-null  int64
#  3   Start Ts   359400 non-null  object
#  4   Uid        359400 non-null  uint64
# dtypes: int64(1), object(3), uint64(1)
# memory usage: 13.7+ MB
#            Source Id           Uid
# count  359400.000000  3.594000e+05
# mean        3.750515  9.202557e+18
# std         1.917116  5.298433e+18
# min         1.000000  1.186350e+13
# 25%         3.000000  4.613407e+18
# 50%         4.000000  9.227413e+18
# 75%         5.000000  1.372824e+19
# max        10.000000  1.844668e+19
#     Device               End Ts  Source Id             Start Ts  \
# 0    touch  2017-12-20 17:38:00          4  2017-12-20 17:20:00
# ...

# %% [markdown]
# El dataset Visits tiene 359,400 entradas, en ninguna columna tiene datos vacíos. Los datos de tiempo de inicio y fin de sesión tienen un formato object, será necesario convertirlos a datetime para poder organizarlos y extraer el tiempo de cada sesión. De estos datos podemos obtener el tiempo promedio por sesión, el tipo de device más popular y el numero de visitas por usuario.

# %%
orders.info()
print()
display(orders.describe())
print()
display(orders.head()
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50415 entries, 0 to 50414
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Buy Ts   50415 non-null  object
#  1   Revenue  50415 non-null  float64
#  2   Uid      50415 non-null  uint64
# dtypes: float64(1), object(1), uint64(1)
# memory usage: 1.2+ MB
#             Revenue           Uid
# count  50415.000000  5.041500e+04
# mean       4.999647  9.098161e+18
# std       21.818359  5.285742e+18
# min        0.000000  3.135781e+14
# 25%        1.220000  4.533567e+18
# 50%        2.500000  9.102274e+18
# 75%        4.890000  1.368290e+19
# max     2633.280000  1.844617e+19
#                 Buy Ts  Revenue                   Uid
# 0  2017-06-01 00:10:00    17.00  10329302124590727494
# 1  2017-06-01 00:25:00     0.55  11627257723692907447
# 2  2017-06-01 00:27:00     0.37  17903680561304213844
# 3  2017-06-01 00:29:00     0.55  16109239769442553005
# ...

# %% [markdown]
# El dataset Orders parece no tener datos nulos en ninguna columna, la columna de la fecha de compra está en formato object, se deve convertir a datetime para poder trabajar con ella. Aqui también podemos ver en el metodo describe el promedio de utilidades por compra, asi como el máximo y mínimo.

# %%
costs.info()
print()
display(costs.describe())
print()
display(costs.head()
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2542 entries, 0 to 2541
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   source_id  2542 non-null   int64
#  1   dt         2542 non-null   object
#  2   costs      2542 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 59.7+ KB
#          source_id        costs
# count  2542.000000  2542.000000
# mean      4.857199   129.477427
# std       3.181581   156.296628
# min       1.000000     0.540000
# 25%       2.000000    21.945000
# 50%       4.000000    77.295000
# 75%       9.000000   170.065000
# max      10.000000  1788.280000
#    source_id          dt  costs
# 0          1  2017-06-01  75.20
# 1          1  2017-06-02  62.25
# 2          1  2017-06-03  36.53
# 3          1  2017-06-04  55.00
# 4          1  2017-06-05  57.08

# %% [markdown]
# En el dataset costs vemos que no hay datos nulos, también se debe convertir la fecha a un formato datetime para poder trabajar con ella y extraer los meses, dias o años. En el metodo describe podemos ver los minimos, máximos y el promedio de las entradas.

# %% [markdown]
# ### Corrección

# %%
# Corregir tipos de datos 
visits['Start Ts'] = pd.to_datetime(visits['Start Ts'])
visits['End Ts'] = pd.to_datetime(visits['End Ts'])

#Duplicados
print("Duplicados en Visits: ", visits.duplicated().sum())
print()

# Verificar cambios
display(visits.info())
# Out:
# Duplicados en Visits:  0
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359400 entries, 0 to 359399
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Device     359400 non-null  object
#  1   End Ts     359400 non-null  datetime64[ns]
#  2   Source Id  359400 non-null  int64
#  3   Start Ts   359400 non-null  datetime64[ns]
#  4   Uid        359400 non-null  uint64
# dtypes: datetime64[ns](2), int64(1), object(1), uint64(1)
# memory usage: 13.7+ MB
# None

# %%
# Corregir tipos de datos 
orders['Buy Ts'] = pd.to_datetime(orders['Buy Ts'])

#Duplicados
print("Duplicados en Orders: ", orders.duplicated().sum())
print()

# Verificar cambios
display(orders.info())
# Out:
# Duplicados en Orders:  0
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50415 entries, 0 to 50414
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Buy Ts   50415 non-null  datetime64[ns]
#  1   Revenue  50415 non-null  float64
#  2   Uid      50415 non-null  uint64
# dtypes: datetime64[ns](1), float64(1), uint64(1)
# memory usage: 1.2 MB
# None

# %%
# Corregir tipos de datos 
costs['dt'] = pd.to_datetime(costs['dt'])

#Duplicados
print("Duplicados en Costs: ", costs.duplicated().sum())
print()

# Verificar cambios
display(costs.info())
# Out:
# Duplicados en Costs:  0
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2542 entries, 0 to 2541
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   source_id  2542 non-null   int64
#  1   dt         2542 non-null   datetime64[ns]
#  2   costs      2542 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 59.7 KB
# None

# %% [markdown]
# Ya que se comprobó que no hay duplicados ni datos nulos en ninguno de los dataframes y se corrigieron los tipos de datos de timestamps, podemos continuar con el análisis de los mismos

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# Buen trabajo con la importación de librerías y carga de datos! La exploración inicial está muy bien realizada, solo te recomendaría que en lugar de print para mostrar los dataframes uses `display()`
# </div>

# %% [markdown]
# ## Informes y cálculo de métricas

# %% [markdown]
# ### Visitas
#
# A continuación se hará un cálculo de las métricas y trazo de gráficos de las visitas al sitio para contestar las siguientes preguntas:
# - ¿Cuántas personas lo usan cada día, semana y mes?
# - ¿Con qué frecuencia los usuarios regresan?
# - ¿Cuántas sesiones hay por día? (Un usuario puede tener más de una sesión).
# - ¿Cuál es la duración de cada sesión?

# %%
#Cálculo de visitas por día semana y mes

visits['session_year'] = visits['Start Ts'].dt.isocalendar().year

visits['session_month'] = visits['Start Ts'].dt.month

visits['session_week'] = visits['Start Ts'].dt.isocalendar().week

visits['session_date'] = visits['Start Ts'].dt.date


dau = visits.groupby(['session_date']).agg({'Uid':'nunique'}).mean()

print('Daily active users average:',int(dau))

wau= visits.groupby(['session_year','session_week']).agg({'Uid': 'nunique'}).mean()

print('Weekly active users average:',int(wau))

mau= visits.groupby(['session_year','session_month']).agg({'Uid':'nunique'}).mean()

print('Monthly active users average:',int(mau))

sticky_wau = dau / wau * 100
print('Sticky wau:', round(sticky_wau), '%')
sticky_mau = dau / mau * 100
print('Sticky mau:',round(sticky_mau), '%')
# Out:
# Daily active users average: 907
# Weekly active users average: 5716
# Monthly active users average: 23228
# Sticky wau: Uid    16.0
# dtype: float64 %
# Sticky mau: Uid    4.0
# dtype: float64 %

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# Muy bien, presentaste los resultados de la manera adecuada
# </div>

# %% [markdown]
# En promedio, hay 907 usuarios activos cada día, y 23,228 usuarios activos por semana y por mes.
# El factor de adherencia semanal es del 16% y el mensual es de 4%.
# Esto nos indica que 16% de los usuarios semanales están activos diariamente en la plataforma, mientras que 4% de los usuarios activos mensualmente están activos diariamente.
# Al ser una empresa de venta de entradas para eventos, no representa una métrica muy significativa, ya que puede haber usuarios que sólamente la usen cuando hay un evento que les interese.

# %%
#Cuantas sesiones hay por día

daily_visits = visits.groupby(['session_date'])['Uid'].count().sort_values()
print(daily_visits)
daily_visits_avg = daily_visits.mean()
print()
print('Promedio de sesiones al día: ',daily_visits_avg)
# Out:
# session_date
# 2018-03-31       1
# 2018-03-30     134
# 2017-08-13     293
# 2017-08-12     296
# 2017-08-06     296
#               ...
# 2018-03-26    1796
# 2018-02-01    1878
# 2017-11-25    2089
# 2018-05-31    2256
# 2017-11-24    4042
# Name: Uid, Length: 364, dtype: int64
#
# Promedio de sesiones al día:  987.3626373626373

# %% [markdown]
# Las visitas diarias tienen un promedio de 987 por día, esto es tomando en cuenta que un usuario puede acceder varias veces al sitio. Se ordenaron los valores para ver cual es el numero más bajo de visitas al día, se observa que el 31 de marzo de 2018 solamente hay un registro, y el día con más visitas fue el 24 de noviembre 2017, con 4,042 visitas.

# %%
sessions_per_user = visits.groupby(['session_year', 'session_month']).agg({'Uid': ['count','nunique']})

sessions_per_user.columns=['n_sessions','n_users']

sessions_per_user['sess_per_user']= sessions_per_user['n_sessions'] / sessions_per_user['n_users']

print(sessions_per_user)
print()
print('Visitas mensuales promedio por usuario: ', sessions_per_user['sess_per_user'].mean())
# Out:
#                             n_sessions  n_users  sess_per_user
# session_year session_month
# 2017         6                   16505    13259       1.244815
#              7                   17828    14183       1.256998
#              8                   14355    11631       1.234202
#              9                   23907    18975       1.259921
#              10                  37903    29692       1.276539
#              11                  43969    32797       1.340641
#              12                  41983    31557       1.330386
# 2018         1                   36939    28716       1.286356
#              2                   37182    28749       1.293332
#              3                   35679    27473       1.298693
#              4                   26515    21008       1.262138
#              5                   26635    20701       1.286653
#
# Visitas mensuales promedio por usuario:  1.2808894945992668

# %% [markdown]
# En promedio, los clientes visitan 1.28 veces el sitio de forma mensual.

# %%
 #Duración de cada sesión
visits['session_duration'] = (
    visits['Start Ts'] - visits['End Ts']
).dt.seconds

visits['session_duration'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# En el gráfico, se puede observar que una gran cantidad de sesiones terminan muy pronto, y el resto no se distribuya de manera uniforme. Es considerablemente más frecuente una sesión más larga. Es por esto que se debe utilizar la moda para calcular la duración promedio de una sesión en lugar de la media.

# %%
asl = visits['session_duration'].mode()
print('Average Session Length (seconds): ', asl)
# Out:
# Average Session Length (seconds):  0    86340
# dtype: int64

# %% [markdown]
# Se puede observar en el gráfico que las sesiones suelen ser largas en este sitio web.

# %% [markdown]
# ### Ventas
#
# Ventas:
#
# - ¿Cuándo empieza la gente a comprar? (En el análisis de KPI, generalmente nos interesa saber el tiempo que transcurre entre el registro y la conversión, es decir, cuando el usuario se convierte en cliente. Por ejemplo, si el registro y la primera compra ocurren el mismo día, el usuario podría caer en la categoría Conversion 0d. Si la primera compra ocurre al día siguiente, será Conversion 1d. Puedes usar cualquier enfoque que te permita comparar las conversiones de diferentes cohortes para que puedas determinar qué cohorte o canal de marketing es más efectivo.)
# - ¿Cuántos pedidos hacen durante un período de tiempo dado?
# - ¿Cuál es el tamaño promedio de compra?
# - ¿Cuánto dinero traen? (LTV)

# %% [markdown]
# Para analizar las conversiones se debe dividir los datos en cohortes para poder comparar entre sí. Se agruparán por mes de registro las visitas y luego se unirán los datos de las ordenes para crear cohortes mensuales.Después se filtrará por los usuarios que hicieron una compra y se calculará la tasa de conversión por cohorte dividiendo el numero de usuarios que compraron entre el numero de usuarios en el cohorte.

# %%
visits['Start Ts'] = pd.to_datetime(visits['Start Ts'])

visits['first_visit_month'] = visits.groupby('Uid')['Start Ts'].transform('min').dt.to_period('M')

orders['Buy Ts'] = pd.to_datetime(orders['Buy Ts'])
merged_data = visits[['Uid', 'first_visit_month']].merge(orders, on='Uid', how='left')

merged_data.head()
# Out:
#                     Uid first_visit_month              Buy Ts  Revenue
# 0  16879256277535980062           2017-12                 NaT      NaN
# 1    104060357244891740           2018-02                 NaT      NaN
# 2   7459035603376831527           2017-07                 NaT      NaN
# 3  16174680259334210214           2018-03 2018-03-09 20:25:00     2.33
# 4   9969694820036681168           2017-12                 NaT      NaN

# %%
# Usuarios únicos por cohorte
users_per_cohort = merged_data.groupby('first_visit_month')['Uid'].nunique()

# Usuarios que compraron por cohorte
buyers_per_cohort = merged_data[~merged_data['Buy Ts'].isna()].groupby('first_visit_month')['Uid'].nunique()

# Tasa de conversión
conversion_rate_per_cohort = (buyers_per_cohort / users_per_cohort) * 100

print(conversion_rate_per_cohort)
# Out:
# first_visit_month
# 2017-06    22.045403
# 2017-07    18.706240
# 2017-08    16.904037
# 2017-09    18.306992
# 2017-10    18.008238
# 2017-11    15.641515
# 2017-12    16.123160
# 2018-01    13.786245
# 2018-02    14.353291
# 2018-03    13.784059
# 2018-04    12.031320
# 2018-05    15.164015
# Freq: M, Name: Uid, dtype: float64

# %%
#gráfico conversion rate
conversion_rate_per_cohort.plot(kind='bar', figsize=(10, 6), title="Tasa de Conversión por Cohorte")
plt.ylabel('Tasa de Conversión (%)')
plt.xlabel('Cohorte (Mes/Año)')
plt.show()

# %% [markdown]
# La tasa de conversión por cohorte tuvo su valor más alto en el grupo de junio 2017, mientras que el más bajo fue en abril 2018.

# %%
# Ingresos totales por cohorte
revenue_per_cohort = merged_data.groupby('first_visit_month')['Revenue'].sum()
print('Ingresos totales por cohorte: ', revenue_per_cohort)

# LTV por cohorte
ltv_per_cohort = revenue_per_cohort / users_per_cohort
print()
print('LTV por cohorte: ', ltv_per_cohort)
# Out:
# Ingresos totales por cohorte:  first_visit_month
# 2017-06    3.929833e+06
# 2017-07    1.686924e+05
# 2017-08    5.441894e+05
# 2017-09    1.229545e+06
# 2017-10    1.710361e+05
# 2017-11    2.471403e+05
# 2017-12    2.175067e+05
# 2018-01    1.341091e+05
# 2018-02    8.197011e+04
# 2018-03    1.452694e+05
# 2018-04    7.686662e+04
# 2018-05    1.604881e+04
# Freq: M, Name: Revenue, dtype: float64
#
# LTV por cohorte:  first_visit_month
# 2017-06    296.389877
# 2017-07     12.838079
# 2017-08     53.451469
# 2017-09     73.607817
# 2017-10      6.584138
# 2017-11      9.070036
# 2017-12      8.607990
# 2018-01      5.927737
# 2018-02      3.692846
# 2018-03      7.055681
# 2018-04      4.893158
# 2018-05      1.050796
# Freq: M, dtype: float64

# %%
revenue_per_cohort.plot(kind='line', figsize=(10, 6), marker='o', title="Ingresos por Cohorte")
plt.ylabel('Ingresos totales')
plt.xlabel('Cohorte (Mes/Año)')
plt.show()

# %%
ltv_per_cohort.plot(kind='line', figsize=(10, 6), marker='o', title="LTV por Cohorte")
plt.ylabel('LTV (Ingresos por Usuario)')
plt.xlabel('Cohorte (Mes/Año)')
plt.show()

# %% [markdown]
# En las dos gráficas anteriores, podemos ver que hay un pico en los ingresos totales y en el LTV en junio y en septiembre. Hay que hacer un análisis más profundo sobre qué acciones pudieron llevar a el aumento de ventas de entradas durante estos meses.

# %%
# Crear columna para el mes/año de la compra
merged_data['buy_month'] = merged_data['Buy Ts'].dt.to_period('M')

# Usuarios únicos que compran por cohorte y mes de compra
cohort_retention = merged_data.pivot_table(
    index='first_visit_month', 
    columns='buy_month', 
    values='Uid', 
    aggfunc='nunique'
)
cohort_retention.head()
# Out:
# buy_month          2017-06  2017-07  2017-08  2017-09  2017-10  2017-11  \
# first_visit_month
# 2017-06             2023.0    231.0    129.0    188.0    257.0    203.0
# 2017-07                NaN   1753.0    135.0    149.0    154.0    153.0
# 2017-08                NaN      NaN   1208.0    156.0    138.0    117.0
# 2017-09                NaN      NaN      NaN   2257.0    365.0    241.0
# 2017-10                NaN      NaN      NaN      NaN   3761.0    476.0
#
# buy_month          2017-12  2018-01  2018-02  2018-03  2018-04  2018-05  \
# first_visit_month
# 2017-06              189.0    155.0    172.0    156.0    114.0    167.0
# 2017-07              133.0    122.0    128.0    115.0     72.0     75.0
# 2017-08              103.0     76.0     76.0     86.0     53.0     58.0
# 2017-09              178.0    111.0    140.0    140.0     69.0     93.0
# 2017-10              292.0    197.0    198.0    177.0    116.0    123.0
#
# buy_month          2018-06
# first_visit_month
# ...

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(cohort_retention, annot=True, fmt='0')
plt.title("Retención de Usuarios por Cohorte")
plt.ylabel('Cohorte (Mes/Año)')
plt.xlabel('Mes de Compra')
plt.show()

# %% [markdown]
# En el gráfico de mapa de calor se puede observar que la retención del cohorte siempre es más fuerte en el primer mes, es decir en el de registro, y de ahí la retencion baja significativamente. Podría ser por el tipo de eventos que hay y la disponibilidad de boletos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# Muy bien analizada esta sección, se complementa muy bien cada gráfica con la conclusión planteada y tienes gráficas bastante detalladas por cohort
# </div>

# %% [markdown]
# ### Marketing
# Marketing:
#  1. ¿Cuánto dinero se gastó?  (Total/por fuente de adquisición/a lo largo del tiempo)
#  2. ¿Cuál fue el costo de adquisición de clientes de cada una de las fuentes?
#  3. ¿Cuán rentables eran las inversiones? (ROMI)

# %% [markdown]
# A continuación se calcularán los costos totales, así como los costos por fuente de la venta y el costo por día

# %%
total_costs = costs['costs'].sum()

costs_by_source = costs.groupby('source_id')['costs'].sum()

costs_over_time = costs.groupby('dt')['costs'].sum()
print('Costos totales: ', total_costs)
print()
print('Costos por canal: ', costs_by_source)
print()
print('Costos por día: ', costs_over_time)
# Out:
# Costos totales:  329131.62
#
# Costos por canal:  source_id
# 1      20833.27
# 2      42806.04
# 3     141321.63
# 4      61073.60
# 5      51757.10
# 9       5517.49
# 10      5822.49
# Name: costs, dtype: float64
#
# Costos por día:  dt
# 2017-06-01     735.26
# 2017-06-02     721.19
# 2017-06-03     450.85
# 2017-06-04     761.16
# 2017-06-05     821.44
#                ...
# 2018-05-27     532.87
# 2018-05-28     619.44
# 2018-05-29     784.79
# 2018-05-30    1183.00
# 2018-05-31    2153.70
# Name: costs, Length: 364, dtype: float64

# %%
# Total de clientes por fuente
customers_by_source = visits.groupby('Source Id')['Uid'].nunique()

# CAC por fuente
cac_by_source = costs_by_source / customers_by_source

print(customers_by_source)
print()
print(cac_by_source)
# Out:
# Source Id
# 1     18999
# 2     26245
# 3     74756
# 4     83525
# 5     56974
# 6         6
# 7        34
# 9      9264
# 10     8067
# Name: Uid, dtype: int64
#
# 1     1.096546
# 2     1.631017
# 3     1.890439
# 4     0.731201
# 5     0.908434
# 6          NaN
# 7          NaN
# 9     0.595584
# 10    0.721766
# dtype: float64

# %%
#Graficar CAC
cac_by_source_sorted = cac_by_source.sort_values(ascending=False)

plt.figure(figsize=(12, 6))
sns.barplot(
    x=cac_by_source_sorted.index.astype(str), 
    y=cac_by_source_sorted.values, 
    palette="YlOrBr"
)

plt.title("Costo de Adquisición de Clientes (CAC) por Fuente", fontsize=16)
plt.xlabel("Fuente de Adquisición", fontsize=12)
plt.ylabel("CAC (Costo por Cliente)", fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

plt.show()

# %% [markdown]
# El gráfico nos permite observar que el costo por cliente más alto es por mucho el 3, más adelante se debe calcular el ROMI de éste para ver si la inversión ha resultado en una buena estrategia de mkt que aumente las ventas.Hay que combinar los datos de visitas, pedidos y costos de marketing para alinear los ingresos y los costos por fuente. También es importante analizar el CAC por cohorte para poder entender mejor los datos y el comportamiento del cliente.

# %%
visits['Cohort'] = pd.to_datetime(visits['Start Ts']).dt.to_period('M')

customers_by_source_cohort = visits.groupby(['Source Id', 'Cohort'])['Uid'].nunique().reset_index()
customers_by_source_cohort.rename(columns={'Uid': 'Customers'}, inplace=True)

costs['Cohort'] = pd.to_datetime(costs['dt']).dt.to_period('M')
costs_by_source_cohort = costs.groupby(['source_id', 'Cohort'])['costs'].sum().reset_index()

cac_data = pd.merge(costs_by_source_cohort, customers_by_source_cohort, 
                    left_on=['source_id', 'Cohort'], 
                    right_on=['Source Id', 'Cohort'], 
                    how='left')

cac_data['CAC'] = cac_data['costs'] / cac_data['Customers']

cac_pivot = cac_data.pivot_table(
    index='Cohort', 
    columns='Source Id', 
    values='CAC'
)

display(cac_pivot)
# Out:
# Source Id        1         2         3         4         5         9   \
# Cohort
# 2017-06    1.158035  1.584452  1.829543  0.966667  0.901178  0.378778
# 2017-07    1.024718  1.314428  1.886522  0.857980  0.804438  0.538327
# 2017-08    1.198753  1.420431  1.798460  1.028239  0.694622  0.406085
# 2017-09    1.076710  1.401718  1.710481  0.965643  0.780442  0.532164
# 2017-10    1.067166  1.446269  1.844280  0.674883  0.766432  0.584286
# 2017-11    0.876401  1.251534  1.670789  0.479945  0.972381  0.459126
# 2017-12    0.856015  1.323015  1.764142  0.651605  0.943832  0.533209
# 2018-01    1.020626  1.312418  1.736286  0.569219  0.936131  0.516676
# 2018-02    1.039359  1.416379  1.638103  0.585482  0.852035  0.532336
# 2018-03    0.827038  1.176004  1.715971  0.607858  0.981925  0.271044
# 2018-04    0.822485  1.235025  1.698668  0.602500  0.712485  0.497987
# 2018-05    0.835769  0.907368  1.761449  0.579273  0.908757  0.480969
#
# Source Id        10
# Cohort
# ...

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(cac_pivot, annot=True, fmt=".2f", cbar_kws={'label': 'Costo de Adquisición (CAC)'})
plt.title("Costo de Adquisición de Clientes (CAC) por Fuente y Cohorte", fontsize=16)
plt.xlabel("Fuente de Adquisición", fontsize=12)
plt.ylabel("Cohorte (Mes)", fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# Es un muy buen análisis hasta este punto, podrías complementar mejor el CAC creando una tabla con pivot_table para tener el CAC por fuente y por cohort, así se aporta más detalle al análisis
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (2da Iteracion)</b> <a class=“tocSkip”></a>
#
# Perfecto, con esto es mucho más detallado el informe
# </div>

# %% [markdown]
# En éste gráfico se observa la misma tendencia que en el anterior, donde el CAC de la fuente 3 es el más alto para todos los cohorts.

# %%
# Agregar la fuente a los pedidos
orders_with_source = orders.merge(visits[['Uid', 'Source Id']], on='Uid', how='left')

# Calcular ingresos por fuente
revenue_by_source = orders_with_source.groupby('Source Id')['Revenue'].sum()

# Calcular costos por fuente
costs_by_source = costs.groupby('source_id')['costs'].sum()

# %%
# Ordenar las fuentes por costos
costs_by_source_sorted = costs_by_source.sort_values(ascending=False)

# Crear la gráfica de barras
plt.figure(figsize=(12, 6))
sns.barplot(
    x=costs_by_source_sorted.index.astype(str), 
    y=costs_by_source_sorted.values, 
    palette="coolwarm"
)

# Personalizar el gráfico
plt.title("Costos por Fuente de Adquisición", fontsize=16)
plt.xlabel("Fuente de Adquisición", fontsize=12)
plt.ylabel("Costos Totales", fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# %% [markdown]
# En los costos generales por fuente también vemos que el 3 es el más alto, a continuación se hará una gráfica que compare los costos vs los ingresos totales por fuente de adquisición.

# %%
# Ordenar las fuentes por ingresos
revenue_by_source_sorted = revenue_by_source.sort_values(ascending=False)

# Crear la gráfica de barras
plt.figure(figsize=(12, 6))
sns.barplot(
    x=revenue_by_source_sorted.index.astype(str), 
    y=revenue_by_source_sorted.values, 
    palette="viridis"
)

# Personalizar el gráfico
plt.title("Ingresos por Fuente de Adquisición", fontsize=16)
plt.xlabel("Fuente de Adquisición", fontsize=12)
plt.ylabel("Ingresos Totales (Revenue)", fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Esta gráfica nos ayuda a ver la diferencia entre costos e ingresos, a continuación se muestran ambas en un mismo gráfico para facilitar la lectura.

# %%
# Combinar ingresos y costos en un DataFrame
combined_data = pd.DataFrame({
    'Revenue': revenue_by_source,
    'Costs': costs_by_source
}).dropna()

# Crear una gráfica de barras agrupadas
x = np.arange(len(combined_data.index))  
width = 0.4  

plt.figure(figsize=(12, 6))
plt.bar(x - width/2, combined_data['Revenue'], width, label='Ingresos')
plt.bar(x + width/2, combined_data['Costs'], width, label='Costos')

# Personalizar el gráfico
plt.title("Ingresos vs Costos por Fuente de Adquisición", fontsize=16)
plt.xlabel("Fuente de Adquisición", fontsize=12)
plt.ylabel("Montos Totales", fontsize=12)
plt.xticks(x, combined_data.index.astype(str), rotation=45, ha='right')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# En éste gráfico se observa claramente que a pesar de tener los costos más altos, la fuente 3 no es de las que más ingresos generan. La 1,2,4 y 5 la superan con menores costos, por lo que sugiere que tienen una mejor métrica ROMI y pueden ser más rentables.

# %%
# Unir ingresos y costos por fuente
romi_data = pd.DataFrame({
    'Revenue': revenue_by_source,
    'Costs': costs_by_source
}).dropna()

# Calcular ROMI
romi_data['ROMI'] = (romi_data['Revenue'] - romi_data['Costs']) / romi_data['Costs']
print(romi_data)
# Out:
#          Revenue      Costs        ROMI
# 1   2.298200e+06   20833.27  109.313944
# 2   2.638189e+06   42806.04   60.631237
# 3   2.966880e+05  141321.63    1.099381
# 4   4.966902e+05   61073.60    7.132649
# 5   1.181477e+06   51757.10   21.827344
# 9   3.634225e+04    5517.49    5.586736
# 10  1.461923e+04    5822.49    1.510821

# %%
romi_data['ROMI'].sort_values(ascending=False).plot(
    kind='bar', figsize=(10, 6), title="ROMI por Fuente de Adquisición"
)
plt.ylabel('ROMI')
plt.xlabel('Fuente de Adquisición')
plt.show()

# %% [markdown]
# En éste gráfico se observa que aunque todas las fuentes tienen un ROMI superior a 0, es decir, recuperan su inversión en ventas, hay estrategias que son mucho más rentables que otras. En este caso, la estrategia 1 genera más ingresos que costos, su ROMI es de 109.31, mientras que otras estrategias más caras y con menos ingresos tienen un ROMI menor, como es el caso de la estrategia 3, con un valor de 1.01.

# %%
revenue_by_source_cohort = visits.merge(orders, on='Uid', how='inner')
revenue_by_source_cohort.rename(columns={'Cohort_y': 'Cohort'}, inplace=True)

revenue_by_source_cohort = revenue_by_source_cohort.groupby(['Source Id', 'Cohort'])['Revenue'].sum().reset_index()

display(revenue_by_source_cohort.head())


romi_data = pd.merge(costs_by_source_cohort, revenue_by_source_cohort, 
                     left_on=['source_id', 'Cohort'], 
                     right_on=['Source Id', 'Cohort'], 
                     how='left')

romi_data['ROMI'] = (romi_data['Revenue'] - romi_data['costs']) / romi_data['costs']

romi_pivot = romi_data.pivot_table(
    index='Cohort', 
    columns='Source Id', 
    values='ROMI'
)

display(romi_pivot)
# Out:
#    Source Id   Cohort    Revenue
# 0          1  2017-06   51524.95
# 1          1  2017-07  111710.63
# 2          1  2017-08   86273.21
# 3          1  2017-09  279308.11
# 4          1  2017-10  187071.49
# Source Id          1           2         3          4          5         9   \
# Cohort
# 2017-06     44.775135   19.444269 -0.034123   2.881919   7.947445  4.331534
# 2017-07    103.122204   26.145840  0.520026   4.914166  13.715457  4.876149
# 2017-08     89.641210   29.276480  0.625652   4.302064  17.599401  7.593942
# 2017-09    184.956225   79.289902  2.200571  11.068440  30.460565  6.575333
# 2017-10     79.782248   57.263711  0.823708   8.750449  19.977399  6.349518
# 2017-11     81.339732   25.018444  0.569251   8.362974  11.048435  6.497512
# 2017-12    118.833402  139.246529  2.814760   9.732458  54.827183  5.944330
# 2018-01     62.367545   51.291873  0.426214   5.454148  15.198761  2.771895
# ...

# %%
# Graficar el heatmap del ROMI
plt.figure(figsize=(12, 8))
sns.heatmap(romi_pivot, annot=True, cmap="coolwarm", fmt=".2f", cbar_kws={'label': 'ROMI (%)'})

plt.title("ROMI por Cohorte y Fuente de Adquisición", fontsize=16)
plt.xlabel("Fuente de Adquisición", fontsize=12)
plt.ylabel("Cohorte (Mes)", fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# En éste gráfico se observa que la fuente 1 tiene un mejor ROMI para casi todos los cohortes, mientras que las fuentes 3 y 10 presentan algunos valores ROMI negativos que no se habían visto en el análisis de ROMI general. Sus costos de adiquisición de clientes son muy altos, por lo que a penas se cubren con las ventas generadas de estas fuentes.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# Muy bien, esta parte también podrías complementar con una gráfica que muestre el ROMI por cohort y fuente
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# Excelente, de esta forma se puede analizar mejor cual cohort fue más rentable
# </div>

# %% [markdown]
# ## Conclusión

# %% [markdown]
# En conclusión, viendo los datos analizados y los gráficos, la recomendación sería invertir en las estrategias 1 y 2 principalmente, ya que generan más ingresos por un menor costo, siendo más rentables para la empresa. En este caso, al ser una plataforma de venta de boletos, es posible que haya clientes que sólamente entren 1 o 2 veces a comprar entradas a un evento que les interesa, se podría también ahcer un análisis de cómo recomendar eventos que les gustarían a los clientes según los cuales han visto o comprado entradas anteriormente, empujándolos a entrar con más frecuencia al sitio.
# Sin embargo, al no ser un sitio en el que se monetiza por cuánto tiempo pasa un usuario en la página, sino por ventas concretadas, es más importante considerar las métricas de conversión de ventas y márketing, para poder concretar más ventas y obtener más utilidades.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario general (2da Iteracion)</b> <a class=“tocSkip”></a>
#
# Buen trabajo con los cambios realizados Natalia! Es importante siempre ir hasta cierto punto de detalle en cuanto a las métricas que se están mostrando por ejemplo aquí llegar al punto de granularidad de mostrar por cohort ayuda mucho a entender al equipo de marketing a ver que estrategias aplicaron con el cohort que es más rentable o en que momento se hizo para poder replicarlo y traer mejor beneficio a la empresa.
#
# Saludos!
# </div>
