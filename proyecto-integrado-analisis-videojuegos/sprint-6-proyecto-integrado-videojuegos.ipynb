# %% [markdown]
# # ¡Hola Natalia! 😊
#
# Mi nombre es **Alejandro Castellanos** y hoy tengo el placer de ser el revisor de tu proyecto.
#
# Voy a revisar todo tu código con detalle, buscando tanto los puntos fuertes como aquellos en los que podrías mejorar. Te dejaré comentarios a lo largo del notebook, destacando lo que has hecho bien y sugiriendo ajustes donde sea necesario. Si encuentro algún error, no te preocupes, te lo haré saber de forma clara y te daré información útil para que puedas corregirlo en la próxima. Si en algún punto tienes comentarios, siéntete libre de dejarlos también. Al final del notebook, te dejaré un comentario general con mi valoración del proyecto. **¡Mi objetivo es que sigas aprendiendo y mejorando con cada paso!**
#
#
# Encontrarás mis comentarios dentro de cajas verdes, amarillas o rojas, es muy importante que no muevas, modifiques o borres mis comentarios, con el fin de tener un seguimiento adecuado de tu proceso.:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si todo está perfecto.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si tu código está bien pero se puede mejorar o hay algún detalle que le hace falta.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si de pronto hace falta algo o existe algún problema con tu código o conclusiones.
# </div>
#
# Puedes responderme de esta forma:
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class=“tocSkip”></a>
# </div>

# %% [markdown]
# <h1>Tabla de Contenido<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introducción" data-toc-modified-id="Introducción-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introducción</a></span></li><li><span><a href="#Exploración-de-datos" data-toc-modified-id="Exploración-de-datos-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Exploración de datos</a></span></li><li><span><a href="#Limpieza-de-datos" data-toc-modified-id="Limpieza-de-datos-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Limpieza de datos</a></span></li><li><span><a href="#Enriquecimiento-de-datos" data-toc-modified-id="Enriquecimiento-de-datos-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Enriquecimiento de datos</a></span></li><li><span><a href="#Análisis-de-datos" data-toc-modified-id="Análisis-de-datos-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Análisis de datos</a></span><ul class="toc-item"><li><span><a href="#Análisis-de-crecimiento" data-toc-modified-id="Análisis-de-crecimiento-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Análisis de crecimiento</a></span></li><li><span><a href="#Efecto-de-las-reseñas-de-expertos-y-usuarios-sobre-las-ventas" data-toc-modified-id="Efecto-de-las-reseñas-de-expertos-y-usuarios-sobre-las-ventas-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Efecto de las reseñas de expertos y usuarios sobre las ventas</a></span></li><li><span><a href="#Juegos-más-vendidos-por-plataforma" data-toc-modified-id="Juegos-más-vendidos-por-plataforma-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Juegos más vendidos por plataforma</a></span></li><li><span><a href="#Géneros-más-populares" data-toc-modified-id="Géneros-más-populares-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Géneros más populares</a></span></li><li><span><a href="#Análisis-por-regiones" data-toc-modified-id="Análisis-por-regiones-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Análisis por regiones</a></span></li></ul></li><li><span><a href="#Pruebas-de-Hipótesis" data-toc-modified-id="Pruebas-de-Hipótesis-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Pruebas de Hipótesis</a></span><ul class="toc-item"><li><span><a href="#Primera-hipótesis:-diferencias-en-las-calificaciones-de-Xbox-ONe-y-PC" data-toc-modified-id="Primera-hipótesis:-diferencias-en-las-calificaciones-de-Xbox-ONe-y-PC-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Primera hipótesis: diferencias en las calificaciones de Xbox ONe y PC</a></span></li><li><span><a href="#Segunda-hipótesis:-diferencias-en-las-calificaciones-para-Acción-y-Deportes" data-toc-modified-id="Segunda-hipótesis:-diferencias-en-las-calificaciones-para-Acción-y-Deportes-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Segunda hipótesis: diferencias en las calificaciones para Acción y Deportes</a></span></li></ul></li><li><span><a href="#Conclusiones" data-toc-modified-id="Conclusiones-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Conclusiones</a></span></li></ul></div>

# %% [markdown]
# # Proyecto Integrado

# %% [markdown]
# Natalia Quintanilla Jiménez | Aspirante a Data Analyst

# %% [markdown]
# ## Introducción
#
# En este proyecto se aplicarán las habilidades obtenidas en los primoros 6 sprints del curso de Data Analyst. Los objetivos son preparar los datos para posteriormente realizar un análisis descriptivo, estadístico y con gráficos para obtener información relevante para Ice, la empresa para la cual realizamos el análisis. Después, se pondrán a prueba las hipótesis en cuanto al comportamiento de los usuarios conforme a diferentes juegos y plataformas.
# Con todo esto se busca identificar patrones para poder predecir el éxito de un juego y planear futuros lanzamientos acorde a ésto.
#
# En la primera parte del proyecto se hará una exploración de los datos proporcionados, identificando si hay algun problema con los mismos como pueden ser datos duplicados, ausentes o en formatos erróneos. El siguiente paso será resolver estos problemas para poder pasar al análisis de los mismos. En el análisis se observará la disrtribución de las ventas conforme a las plataformas, géneros y años de lanzamiento. También se observarán las reseñas tanto de los usuarios como de los expertos y cómo éstas afectan las ventas de un juego.
#
# Finalmente, se llegará a una conclusión con insights específicos que sean útiles para Ice en cuanto a las ventas y preferencias de los usuarios, para poder planear los futuros lanzamientos conforme a los datos reales de sus ventas pasadas.

# %% [markdown]
# ## Exploración de datos

# %%
# Importar las librerías necesarias
import pandas as pd
import numpy as np 
from scipy import stats as st
from matplotlib import pyplot as plt
import seaborn as sns

# %%
#Leer la ruta del archivo
games_df = pd.read_csv('/datasets/games.csv')

# %%
#información general de los datos
games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
#Una muestra de los datos

games_df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
#Buscar duplicados y nulos 
print('El numero de duplicados es: ', games_df.duplicated().sum())
print()
print('El número de ausentes es:')
print(games_df.isna().sum() )
# Out:
# El numero de duplicados es:  0
#
# El número de ausentes es:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# NA_sales              0
# EU_sales              0
# JP_sales              0
# Other_sales           0
# Critic_Score       8578
# User_Score         6701
# Rating             6766
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Natalia hiciste un gran trabajo importando la liberías necesarias y el dataset del proyecto. Además has comprobado si tenemos datos duplicados y faltantes. Eso sienta una base importante para el desarrollo del resto del proyecto.
#
# </div>

# %% [markdown]
# ## Limpieza de datos

# %% [markdown]
# En el apartado anterior, podemos ver que los títulos de las columnas de nuestros datos están en un formato de mayúsculas y minúsculas. Para hacer más facil su manipulación se convertirán todos los títulos a minúsculas.

# %%
#cambiar columnas a minusculas
games_df.columns = games_df.columns.str.lower()
games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# Ahora, se corregirán los datos que tienen tipos incorrectos, en este caso, year_of_release a numero entero y user_score a número, ya que es un objeto. Se utiliza 'coerce' en user_score ya que el tipo de dato era un objeto y necesitamos un valor numérico. Los valores que tenian el texto NaN ahora son valores nulos. En year_of_release se ignoraron los errores ya que no tenemos los datos correctos de los años, y rellenar con 0 o con otro año puede afectar el comportamiento de los datos. Los demás datos tienen formato correcto.

# %%
#cambiar tipos de datos
games_df['user_score'] = pd.to_numeric(games_df['user_score'], errors='coerce')
games_df['year_of_release']= games_df['year_of_release'].astype('int', errors='ignore')

games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           9949 non-null   object
# dtypes: float64(7), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# Como ya se vio anteriormente, no hay datos duplicados, sin embargo, si hay datos ausentes en algunas columnas:

# %%
#encontrar valores ausentes
print('El número de ausentes es:')
print(games_df.isna().sum() )
# Out:
# El número de ausentes es:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         9125
# rating             6766
# dtype: int64

# %% [markdown]
# Se observa que no hay datos ausentes en cuanto a las plataformas o en cuanto a las ventas, es por esto que todas las filas de nuestros datos contienen información relevante. Para las columnas de datos object (name, genre y rating), podemos rellenar con la palabra 'Unkown', ya que nos ayuda a reducir los valores ausentes sin eliminar parte de las ventas.

# %%
#limpiar columnas
columns_to_clean = ['name' , 'genre' , 'rating']

for column in columns_to_clean:
    games_df[column] = games_df[column].fillna('unknown')

# %%
#revisar valores ausentes
print('El número de ausentes es:')
print(games_df.isna().sum() )
# Out:
# El número de ausentes es:
# name                  0
# platform              0
# year_of_release     269
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         9125
# rating                0
# dtype: int64

# %% [markdown]
# Para comprobar que los valores de critic score y user score estén en los rangos correctos. El critic score dbe estar entre 0 y 100, y el user score entre 0 y 10

# %%
#maximos y minimos
print('El máximo valor user score: ',games_df['user_score'].max()
, 'El mínimo valor user score: ', games_df['user_score'].min())
# Out:
# El máximo valor user score:  9.7 El mínimo valor user score:  0.0

# %%
#maximos y minimos
print('El máximo valor critic score: ',games_df['critic_score'].max()
, 'El mínimo valor critic score: ', games_df['critic_score'].min())
# Out:
# El máximo valor critic score:  98.0 El mínimo valor critic score:  13.0

# %% [markdown]
# No podemos rellenar los valores de critic score o user score con un promedio o algo parecido, ya que es una variable que puede depender del género así como de cómo se recibieron los juegos en el mercado. Se dejarán vacíos estos valores ya que así no se tomarán en cuenta para los cálculos que se lleguen a hacer con estas columnas, pero sin eliminarlos ya que no queremos perder los demás datos para cada juego. Es posible que estos datos no se hayan determinado aún, por lo que rellenarlos con algún valor modificaría el resultado del análisis.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Excelente manejo de los datos, hiciste los ajustes necesarios, además tomaste decisions válidad respecto a los datos faltantes. Cuando se trata de análisis de datos se debe evitar incluir datos sintéticos que puedan cambiar el comportamiento de los datos o generar sesgos sobre los mismos.
#
# </div>

# %% [markdown]
# ## Enriquecimiento de datos

# %% [markdown]
# En esta parte del proyecto se va a enriquecer la tabla existente con datos que se puedan calcular a partir de los que ya están en la tabla, por ejemplo las ventas totales para cada juego.

# %%
#ventas totales
games_df['total_sales'] = games_df['na_sales'] + games_df['eu_sales'] + games_df['jp_sales'] + games_df['other_sales']

# %%
games_df.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score   rating  \
# 0     28.96      3.77         8.45          76.0         8.0        E
# 1      3.58      6.81         0.77           NaN         NaN  unknown
# 2     12.76      3.79         3.29          82.0         8.3        E
# 3     10.93      3.28         2.95          80.0         8.0        E
# 4      8.89     10.22         1.00           NaN         NaN  unknown
#
#    total_sales
# 0        82.54
# 1        40.24
# 2        35.52
# ...

# %% [markdown]
# Para saber qué datos tenemos, es importante explorar las categorías que hay en diferentes datos. En especial en las que categorizan a los datos de alguna forma, como plataforma, género y rating.

# %%
games_df['platform'].value_counts(dropna = False)
# Out:
# PS2     2161
# DS      2151
# PS3     1331
# Wii     1320
# X360    1262
# PSP     1209
# PS      1197
# PC       974
# XB       824
# GBA      822
# GC       556
# 3DS      520
# PSV      430
# PS4      392
# N64      319
# XOne     247
# SNES     239
# SAT      173
# WiiU     147
# 2600     133
# GB        98
# NES       98
# DC        52
# GEN       29
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# PCFX       1
# GG         1
# Name: platform, dtype: int64

# %%
games_df['rating'].value_counts(dropna = False)
# Out:
# unknown    6766
# E          3990
# T          2961
# M          1563
# E10+       1420
# EC            8
# RP            3
# K-A           3
# AO            1
# Name: rating, dtype: int64

# %%
games_df['genre'].value_counts(dropna = False)
# Out:
# Action          3369
# Sports          2348
# Misc            1750
# Role-Playing    1498
# Shooter         1323
# Adventure       1303
# Racing          1249
# Platform         888
# Simulation       873
# Fighting         849
# Strategy         683
# Puzzle           580
# unknown            2
# Name: genre, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Muy buen trabajo con este análisis preliminar de los datos.
#
# </div>

# %% [markdown]
# ## Análisis de datos

# %% [markdown]
# Mira cuántos juegos fueron lanzados en diferentes años. ¿Son significativos los datos de cada período?

# %%
games_df['year_of_release'].value_counts(dropna = False)
# Out:
# 2008.0    1427
# 2009.0    1426
# 2010.0    1255
# 2007.0    1197
# 2011.0    1136
# 2006.0    1006
# 2005.0     939
# 2002.0     829
# 2003.0     775
# 2004.0     762
# 2012.0     653
# 2015.0     606
# 2014.0     581
# 2013.0     544
# 2016.0     502
# 2001.0     482
# 1998.0     379
# 2000.0     350
# 1999.0     338
# 1997.0     289
# NaN        269
# 1996.0     263
# 1995.0     219
# 1994.0     121
# 1993.0      62
# 1981.0      46
# 1992.0      43
# 1991.0      41
# 1982.0      36
# 1986.0      21
# 1983.0      17
# 1989.0      17
# 1990.0      16
# 1987.0      16
# 1988.0      15
# 1984.0      14
# 1985.0      14
# 1980.0       9
# Name: year_of_release, dtype: int64

# %% [markdown]
# Tenemos datos desde 1980 hasta 2016, podemos considerar que a pesar de que la tecnología y consolas ha cambiado en las últimas décadas, las preferencias por qué tipo de juegos e información sobre ventas sigue siendo relevante para nuestro análisis. Sin embargo, para poder proyectar para 2017, se hará una selección de los datos más relevantes. Para saber a partir de qué año se debe tomar en cuenta, se visualizará con gráficos las plataformas más populares y sus ventas por año, para poder determinar cuánto tiempo pasa para que una plataforma siga siendo relevante.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Natalia has obtenido correctamente los datos de lanzamiento por año, pero recuerda que los seres humanos somo más visuales, si queremos identificar tendencias o patrones, por lo que siempre es recomendable acompañar los valors numéricos con gráficas.
#
# </div>

# %%
sales_by_platform = games_df.groupby('platform')['total_sales'].sum().sort_values(ascending=False)
print(sales_by_platform.head())
# Out:
# platform
# PS2     1255.77
# X360     971.42
# PS3      939.65
# Wii      907.51
# DS       806.12
# Name: total_sales, dtype: float64

# %%
sales_by_platform.plot(kind='bar', figsize=(10, 6))
plt.title('Ventas totales por consola')
plt.ylabel('Ventas (millones)')
plt.xlabel('Consolas')
plt.show()

# %% [markdown]
# Ahora, se elegirán las plataformas con más ventas históricas y se agruparán loa juegos por año para ver cómo se comparan las ventas a lo largo de los años. Esto es para saber cuánto tiempo dura la popularidad de las diferentes plataformas.

# %%
top_platforms = sales_by_platform.head(15).index

df_top = games_df[games_df['platform'].isin(top_platforms)]

sales_by_year = df_top.groupby(['year_of_release', 'platform'])['total_sales'].sum().unstack()

sales_by_year.plot(kind='line', figsize=(10, 6))
plt.title('Distribución de ventas por año (plataformas más exitosas)')
plt.ylabel('Ventas (millones)')
plt.xlabel('Año')
plt.show()

# %% [markdown]
# Con la gráfica anterior podemos ver que las ventas de las plataformas suben rápidamente en su lanzamiento pero a los pocos años bajan y se vuelven menos populares hasta despaarecer. De cualquier forma, se tiene que hacer un esudio más exacto para que podamos saber cuántos años de datos son relevantes para el análisis.
# A continuación, se calcula el promedio de años que una plataforma se mantiene activa en cuanto a las ventas totales. Para esto, primero se visualizan plataformas que antes tenían ventas pero que ya no. Se utilizó el año 2000 como parámetro de filtrado, 15 años antes de los datos presentados.

# %%
# Encontrar plataformas con ventas en el pasado
past_sales = games_df.groupby('platform')['year_of_release'].max()

# Ver plataformas que no tienen ventas recientes (por ejemplo, después de 2000)
vintage_platforms = past_sales[past_sales < 2000]
print('Plataformas que solían ser populares pero ya no tienen ventas:')
print(vintage_platforms)
# Out:
# Plataformas que solían ser populares pero ya no tienen ventas:
# platform
# 2600    1989.0
# 3DO     1995.0
# GEN     1994.0
# GG      1992.0
# NES     1994.0
# NG      1996.0
# PCFX    1996.0
# SAT     1999.0
# SCD     1994.0
# SNES    1999.0
# TG16    1995.0
# Name: year_of_release, dtype: float64

# %% [markdown]
# Ahora se calcula el tiempo de vida de las plataformas. Para esto, calculamos el primer y ultimo año en el que una plataforma tuvo ventas, después con estos datos agregamos una columna llamada 'lifespan' o tiempo de vida, en la que se calculan los años activos. Después se toma un promedio de estos años para tener el dato de cuántos años duran las ventas de una plataforma en promedio.

# %%
# Calcular el primer y último año de ventas para cada plataforma
sales_active_years = games_df.groupby('platform')['year_of_release'].agg(['min', 'max'])

# Añadir una columna de la duración de vida de cada plataforma
sales_active_years['lifespan'] = sales_active_years['max'] - sales_active_years['min']
print(sales_active_years)

# Promedio del tiempo que tardan en desaparecer las plataformas
avg_lifespan = sales_active_years['lifespan'].mean()
print(f'El promedio de duración de las plataformas es de {avg_lifespan} años.')
# Out:
#              min     max  lifespan
# platform
# 2600      1980.0  1989.0       9.0
# 3DO       1994.0  1995.0       1.0
# 3DS       2011.0  2016.0       5.0
# DC        1998.0  2008.0      10.0
# DS        1985.0  2013.0      28.0
# GB        1988.0  2001.0      13.0
# GBA       2000.0  2007.0       7.0
# GC        2001.0  2007.0       6.0
# GEN       1990.0  1994.0       4.0
# GG        1992.0  1992.0       0.0
# N64       1996.0  2002.0       6.0
# NES       1983.0  1994.0      11.0
# NG        1993.0  1996.0       3.0
# PC        1985.0  2016.0      31.0
# PCFX      1996.0  1996.0       0.0
# PS        1994.0  2003.0       9.0
# PS2       2000.0  2011.0      11.0
# PS3       2006.0  2016.0      10.0
# PS4       2013.0  2016.0       3.0
# PSP       2004.0  2015.0      11.0
# PSV       2011.0  2016.0       5.0
# SAT       1994.0  1999.0       5.0
# SCD       1993.0  1994.0       1.0
# SNES      1990.0  1999.0       9.0
# TG16      1995.0  1995.0       0.0
# ...

# %% [markdown]
# En promedio, el tiempo de vida activo de una plataforma es de 7.61 años. Basándonos en esto, hay que tomar en cuenta lo siguiente:
#
# Considerar plataformas activas en los últimos 7 años: Estas plataformas aún pueden ser relevantes y tener potencial en el año entrante.
# Identificar tendencias de plataformas emergentes: Revisar las plataformas que han aparecido en los últimos 1-3 años, ya que suelen tener un crecimiento rápido si están ganando popularidad.
# Descartar plataformas que han desaparecido o mostrado declive: Si una plataforma no ha tenido ventas en los últimos 2-3 años, probablemente ya no sea relevante para el próximo año.

# %%
#Filtrar los juegos tomando en cuenta el promedio de duracion de las plataformas
current_year = 2016
recent_games_df = games_df[games_df['year_of_release'] >= (current_year - (avg_lifespan))]

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Has realizado un magnífico trabajo obteniendo información sobre las ventas de juegos y su relación con las consolas y años. Adicionalmente, tus observaciones son bastante pertinentes con respecto a los datos obtenidos, dandole un mayor valor.
#
# </div>

# %% [markdown]
# ### Análisis de crecimiento

# %% [markdown]
# A continuación, se mostrarán las plataformas con mayor crecimiento de ventas en los últimos 3 años, junto con lo que representan estos últimos 3 años de ventas:

# %%
# Agrupar por plataforma y calcular el crecimiento en los últimos 3 años
growing_games_df = recent_games_df[recent_games_df['year_of_release'] >= (current_year - 3)]
growing_platforms = growing_games_df.groupby('platform')['total_sales'].sum().sort_values(ascending=False)

# Ver plataformas con mayor crecimiento en los últimos 3 años
print('Plataformas con mayor crecimiento en los últimos 3 años:')
display(growing_platforms)

growing_platforms.plot(kind='bar', figsize=(10, 6))
plt.title('Plataformas con mayor crecimiento en los últimos 3 años:')
plt.ylabel('Ventas (millones)')
plt.xlabel('Consolas')
plt.show()
# Out:
# Plataformas con mayor crecimiento en los últimos 3 años:
# platform
# PS4     314.14
# PS3     181.43
# XOne    159.32
# 3DS     143.25
# X360    136.80
# WiiU     64.63
# PC       39.43
# PSV      32.99
# Wii      13.66
# PSP       3.50
# DS        1.54
# Name: total_sales, dtype: float64

# %% [markdown]
# A continuación se calculan las plataformas nuevas,  y sus ventas en los ultimos años:

# %%
new_platforms = recent_games_df[recent_games_df['year_of_release'] >= (current_year - 2)].groupby('platform')['total_sales'].sum().sort_values(ascending = False)
print('Plataformas nuevas con sus ventas en los últimos 2 años:')
print(new_platforms)

new_platforms.plot(kind='bar', figsize=(10, 6))
plt.title('Plataformas nuevas y sus ventas en los últimos 2 años:')
plt.ylabel('Ventas (millones)')
plt.xlabel('Consolas')
plt.show()
# Out:
# Plataformas nuevas con sus ventas en los últimos 2 años:
# platform
# PS4     288.15
# XOne    140.36
# 3DS      86.68
# PS3      68.18
# X360     48.22
# WiiU     42.98
# PC       27.05
# PSV      22.40
# Wii       5.07
# PSP       0.36
# Name: total_sales, dtype: float64

# %% [markdown]
# A continuación buscamos las plataformas que lanzaron juegos hace más tiempo, podemos ver su último año de lanzamiento lo que nos da información sobre su uso:

# %%
declining_platforms = recent_games_df.groupby('platform')['year_of_release'].max()
declining_platforms = declining_platforms[declining_platforms < (current_year - 1)].sort_values()
print('Plataformas que podrían desaparecer y su último año de lanzamiento:')
print(declining_platforms)
# Out:
# Plataformas que podrían desaparecer y su último año de lanzamiento:
# platform
# PS2    2011.0
# DS     2013.0
# Name: year_of_release, dtype: float64

# %% [markdown]
# Ahora se hará un diagrama de caja para las ventas totales de todos los juegos, por plataforma, para los juegos recientes.

# %%
# Crear el diagrama de caja
plt.figure(figsize=(12, 8))
sns.boxplot(x='platform', y='total_sales', data=recent_games_df)

# Título y etiquetas
plt.title('Diagrama de caja de las ventas globales por plataforma')
plt.xlabel('Plataformas')
plt.ylabel('Ventas Globales (millones)')
plt.yscale('log')
plt.xticks(rotation=45) 
plt.show()

# %% [markdown]
# En el diagrama anterior podemos ver que por los datos atípicos es dificil observar el diagrama para cada plataforma. Esto puede ser por que hay juegos con ventas muy por encima que otros. Para comparar las ventas promedio entre plataformas, podemos calcular la media y la mediana para cada plataforma, lo cual nos ayudará a identificar qué plataformas tienen mejor rendimiento en términos de ventas.

# %%
# Agrupar por plataforma y calcular la media y la mediana de las ventas globales
avg_sales = recent_games_df.groupby('platform')['total_sales'].agg(['mean', 'median']).sort_values(by='mean', ascending=False)

# Mostrar los resultados
print(avg_sales)
# Out:
#               mean  median
# platform
# PS4       0.801378    0.20
# X360      0.787207    0.27
# PS3       0.683796    0.25
# XOne      0.645020    0.22
# WiiU      0.559116    0.22
# Wii       0.554761    0.18
# 3DS       0.503535    0.12
# DS        0.267352    0.10
# PC        0.236980    0.06
# PS2       0.230426    0.10
# PSP       0.154054    0.06
# PSV       0.125431    0.05

# %% [markdown]
# Lo que observamos son muchos puntos fuera de los bigotes, lo que significa que hay pocos juegos con ventas excepcionales, mientras que la mayoría tiene ventas más bajas. Estos valores atípicos de juegos con ventas excepcionales hacen que las ventas promedio se eleven con respecto al resto de los datos, en la lista de medias y medianas de las ventas totales, podemos observar que en casi todas las plataformas, la media está bastante por encima de la mediana. Por ejemplo, en el caso de Wii, se observa que hay un juego con más de 30 millones en ventas, sin embargo la mayoría de los datos que vemos dentro de los bigotes está muy por debajo de los 5 millones en ventas. La media de esta plataforma es de 0.55 millones mientras que su mediana es de tan solo 0.18 millones.
#
# Se puede observar que las ventas más elevadas son por juegos atípicos que son los más populares, y son pocos los juegos con esa cantidad de ventas.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Excelente análisis de las gráficas obtenidas, has interpretado de manera correcta la información.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# En el caso del *box-plot*, cuando tengas ese comportamiento donde la caja no se logra ver de manera clara, puedes optar por complementar la información con un *box-plot* donde uses una escala logarítmica en el eje Y, para esto puedes usar lo siguiente:
#
#     plt.yscale('log')
#
#
# </div>

# %% [markdown]
# ### Efecto de las reseñas de expertos y usuarios sobre las ventas
# A continuación se continuará con el análisis de los datos, esta vez teniendo en cuenta las reseñas de los profesionales y los usuarios, y cómo afectan las reseñas a las ventas. Se tomarán los datos de recent_games_df, ya que son los datos más recientes los que nos interesan para poder predecir y tomar decisiones para el proximo año.

# %%
# Gráfico de dispersión para las reseñas de usuarios vs ventas para todas las plataformas
plt.figure(figsize=(10, 6))
sns.scatterplot(x='user_score', y='total_sales', data=recent_games_df, hue='platform')  # Usamos 'hue' para diferenciar las plataformas
plt.title('Reseñas de Usuarios vs Ventas (Plataformas recientes)')
plt.xlabel('Reseñas de Usuarios')
plt.ylabel('Ventas (millones)')
plt.show()

# Gráfico de dispersión para las reseñas de profesionales vs ventas para todas las plataformas
plt.figure(figsize=(10, 6))
sns.scatterplot(x='critic_score', y='total_sales', data=recent_games_df, hue='platform')
plt.title('Reseñas de Profesionales vs Ventas (Plataformas recientes)')
plt.xlabel('Reseñas de Profesionales')
plt.ylabel('Ventas (millones)')
plt.show()

# %% [markdown]
# En el gráfico vemos la dispersión de las reseñas tanto de usuarios como de profesionales respecto a las ventas. Cada punto representa un juego, y su color nos indica la plataforma. A simple vista se observa que hay más ventas en los juegos con más calificación de ambos casos, pero primero hay que comprobar si existe una correlación entre ambas variables.

# %%
# Calcular la correlación entre reseñas de usuarios y ventas 
user_correlation = recent_games_df['user_score'].corr(recent_games_df['total_sales'])
print(f'Correlación global entre reseñas de usuarios y ventas: {user_correlation}')

# Calcular la correlación entre reseñas de profesionales y ventas 
critic_correlation = recent_games_df['critic_score'].corr(recent_games_df['total_sales'])
print(f'Correlación global entre reseñas de profesionales y ventas: {critic_correlation}')
# Out:
# Correlación global entre reseñas de usuarios y ventas: 0.07143229306693606
# Correlación global entre reseñas de profesionales y ventas: 0.2953615631654061

# %% [markdown]
# Como se puede observar en el caso de las reseñas de usuarios, una correlación de 0.07 indica una correlación muy débil o prácticamente inexistente. Esto sugiere que no hay una relación significativa entre las reseñas de los usuarios y las ventas de los juegos. En otras palabras, la variación en las reseñas de los usuarios no influye de manera notable en las ventas de los juegos. Las ventas pueden estar determinadas por otros factores, como la popularidad de la franquicia, la publicidad, o la exclusividad de los juegos, más que por las reseñas de los usuarios.
#
# En el caso de las reseñas de los críticos, una correlación de 0.29 indica una correlación baja pero positiva. Esto sugiere que hay una relación leve entre las reseñas y las ventas. Aunque no es una correlación fuerte, sí existe una tendencia en la que las mejores reseñas de profesionales pueden estar asociadas con un aumento en las ventas, pero no son el principal factor que determina el éxito de las ventas. Otros elementos (como el marketing o la popularidad de ciertos títulos) pueden jugar un papel más importante.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Excelente trabajo Natalia, has logrado hacer una valoración de la correlación de los datos de reseña y ventas. Como bien comentas, se presenta una correlación débil.
#
# </div>

# %% [markdown]
# ### Juegos más vendidos por plataforma
# Vamos a analizar los 3 juegos más vendidos por plataforma dentro de los juegos recientes.

# %%
top_selling_games = recent_games_df.groupby('platform').apply(lambda x: x.nlargest(3, 'total_sales')).reset_index(drop=True)

print(top_selling_games[['platform', 'name', 'total_sales']])
# Out:
#    platform                                       name  total_sales
# 0       3DS                        Pokemon X/Pokemon Y        14.60
# 1       3DS                               Mario Kart 7        12.65
# 2       3DS  Pokemon Omega Ruby/Pokemon Alpha Sapphire        11.68
# 3        DS                Pokemon Black/Pokemon White        15.13
# 4        DS       Pokemon HeartGold/Pokemon SoulSilver        11.77
# 5        DS            Pokemon Black 2/Pokemon White 2         8.06
# 6        PC                                 The Sims 3         8.01
# 7        PC                                 Diablo III         5.14
# 8        PC             StarCraft II: Wings of Liberty         4.83
# 9       PS2                  Dance Dance Revolution X2         2.22
# 10      PS2                             FIFA Soccer 10         1.70
# 11      PS2                  Pro Evolution Soccer 2010         1.56
# 12      PS3                         Grand Theft Auto V        21.05
# ...

# %%
# Gráfico de barras para comparar las ventas de los juegos más vendidos por plataforma
plt.figure(figsize=(14, 8))
sns.barplot(x='name', y='total_sales', hue='platform', data=top_selling_games)

# Título y etiquetas
plt.title('Comparación de las ventas de los juegos más vendidos en diferentes plataformas')
plt.xlabel('Juegos')
plt.ylabel('Ventas Globales (millones)')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Podemos ver que  hay juegos que son exclusivos para una plataforma, como wii sports resort o wii fit plus sólamente existen para wii. Sin embargo hay otros juegos, como Grand Theft Auto V o Call Of Duty que existen para más de una plataforma y las ventas se distribuyen entre éstas. La consola que tienen o prefieren los usuarios puede afectar las ventas, así como qué juegos están disponibles para qué plataformas.
# Se puede observar que los juegos con mayores ventas son exclusivos a una plataforma, como lo vemos con los juegos de wii, ya que no se distribuyen las ventas entre diferentes plataformas.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Natalia has elegido de manera correcta una visualización para mostrar los datos de top ventas por consola.
#
# Otro tipo de gráfico que podría servir para esta información es [TreeMap](https://datavizproject.com/data-type/treemap/). Te invito a que lo revises por si te interesa.
#
# </div>

# %% [markdown]
# ### Géneros más populares
#
# A continuación se agruparán los datos por su género, ya que este factor puede afectar también en las ventas totales.

# %%
sales_by_genre = recent_games_df.groupby('genre')['total_sales'].sum().reset_index()

sales_by_genre = sales_by_genre.sort_values(by='total_sales', ascending=False)

print(sales_by_genre)
# Out:
#            genre  total_sales
# 0         Action       810.78
# 8        Shooter       549.03
# 10        Sports       465.76
# 7   Role-Playing       362.59
# 3           Misc       310.37
# 4       Platform       160.25
# 6         Racing       156.37
# 2       Fighting       113.49
# 9     Simulation       104.67
# 1      Adventure        81.23
# 11      Strategy        48.13
# 5         Puzzle        40.39

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='total_sales', y='genre', data=sales_by_genre)
plt.title('Distribución de Ventas Globales por Género')
plt.xlabel('Ventas Globales (millones)')
plt.ylabel('Género')
plt.show()

# %% [markdown]
# Se puede observar que el género más popular es acción, ya que genera más ventas que cualquier otro género. Después le sigue 'shooter', deportes y juegos de rol. La popularidad de éstos géneros se puede stribuir a diferentes factores, como la facilidad del juego, la historia dentro del juego, la conección online para jugar con otras personas o la existencia de fanáticos de las precuelas de los mismos.
# Los géneros con menos ventas son puzzle, estrategia y aventura, esto se puede deber a que hay menos videojuegos de este estilo, con un público más nicho.
# Estos datos nos llevan a pensar que las tendencias del mercado actual de videojuegos son que los juegos de acción son los más populares.
# También hay que tomar en cuenta las categorías medias, como juegos de carreras o la categoria miscelanea, que a pesar de no ser los más populares tienen ventas significativas y un público que los compra.
# Estos datos nos indican que un juego de acción tiene más probabilidad de tener ventas altas, sin embargo también tiene más competencia, por lo que es importante generar una buena estrategia de márketing para lograr posicionarlo en el mercado.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Excelente análisis Natalia.
# </div>

# %% [markdown]
# ### Análisis por regiones

# %% [markdown]
# A continuación se verá el comportamiento de ventas y usuarios divididos por sus regiones (Norte América, Japón y Europa). Se buscarán las 5 plataformas más populares en cada región, así como los géneros más vendidos. También se busca ver el efecto de la clasificación de los juegos sobre las ventas, y ver si hay una correlación entre ambos. Para ésto se utilizarán los datos recientes que ya se apartaron previamente.

# %%
na_platforms = recent_games_df.groupby('platform')['na_sales'].sum().nlargest(5)
jp_platforms = recent_games_df.groupby('platform')['jp_sales'].sum().nlargest(5)
eu_platforms = recent_games_df.groupby('platform')['eu_sales'].sum().nlargest(5)

print("Top 5 plataformas en NA:")
print(na_platforms)
print("Top 5 plataformas en JP:")
print(jp_platforms)
print("Top 5 plataformas en EU:")
print(eu_platforms)
# Out:
# Top 5 plataformas en NA:
# platform
# X360    408.18
# PS3     291.90
# Wii     235.75
# DS      120.61
# PS4     108.74
# Name: na_sales, dtype: float64
# Top 5 plataformas en JP:
# platform
# 3DS    100.62
# PS3     68.29
# DS      52.11
# PSP     50.39
# Wii     34.32
# Name: jp_sales, dtype: float64
# Top 5 plataformas en EU:
# platform
# PS3     255.00
# X360    196.72
# PS4     141.09
# Wii     124.22
# PC       82.32
# Name: eu_sales, dtype: float64

# %%
df_top_platforms = pd.DataFrame({
    'NA': na_platforms,
    'EU': eu_platforms,
    'JP': jp_platforms
}) 

df_top_platforms.plot(kind='bar', figsize=(10, 6))
plt.title('Comparación de plataformas principales por región')
plt.ylabel('Ventas (millones)')
plt.show()

# %% [markdown]
# En el gráfico anterior se muestran las plataformas más populares en todas las regiones. Tanto PS3 y Wii están en el top 5 de las 3 regiones, lo que indica que tienen más ventas globales. También se puede observar que tanto x360 como ps4 están en el top de NA y EU, con las ventas de x360 siendo mayores. Otra observación es que en japón son más populares las consolas portables, como el 3DS, DS, y PSP.
# Todos estos datos parecen indicar que son mercados distintos y que las estrategias de marketing y ventas deberían estar diseñadas acorde a esto. A continuación se hará el analisis para los géneros más populares por región.

# %%
na_genres = recent_games_df.groupby('genre')['na_sales'].sum().nlargest(5)
jp_genres = recent_games_df.groupby('genre')['jp_sales'].sum().nlargest(5)
eu_genres = recent_games_df.groupby('genre')['eu_sales'].sum().nlargest(5)

print("Top 5 generos en NA:")
print(na_genres)
print("Top 5 generos en JP:")
print(jp_genres)
print("Top 5 generos en EU:")
print(eu_genres)
# Out:
# Top 5 generos en NA:
# genre
# Action          361.72
# Shooter         276.37
# Sports          227.66
# Misc            164.40
# Role-Playing    130.83
# Name: na_sales, dtype: float64
# Top 5 generos en JP:
# genre
# Role-Playing    120.61
# Action           84.16
# Misc             30.09
# Sports           25.32
# Platform         20.65
# Name: jp_sales, dtype: float64
# Top 5 generos en EU:
# genre
# Action          271.91
# Shooter         192.30
# Sports          158.51
# Misc             86.27
# Role-Playing     83.56
# Name: eu_sales, dtype: float64

# %%
df_top_genres = pd.DataFrame({
    'NA': na_genres,
    'EU': eu_genres,
    'JP': jp_genres
}) 

df_top_genres.plot(kind='bar', figsize=(10, 6))
plt.title('Comparación de géneros principales por región')
plt.ylabel('Ventas (millones)')
plt.show()

# %% [markdown]
# En el gráfico se observa que el género más popular coincide con el más popular a nivel mundial, el género de acción. Sin embargo, el mercado de JP no participa en los juegos de shooter, y prefieren los juegos de rol sobre todos los demás. Las diferencias culturales pueden ser un factor que afecte el género de juegos por los que se tiene una preferencia y hay que tomarlas en cuenta.

# %%
na_score = recent_games_df.groupby('rating')['na_sales'].sum()
eu_score = recent_games_df.groupby('rating')['eu_sales'].sum()
jp_score = recent_games_df.groupby('rating')['jp_sales'].sum()

scores_df = pd.DataFrame({
    'NA': na_score,
    'EU': eu_score,
    'JP': jp_score
})

scores_df.plot(kind='bar', figsize=(10, 6))
plt.title('Impacto de las clasificaciones en las ventas por región')
plt.ylabel('Ventas (millones)')
plt.show()

# %% [markdown]
# En el gráfico se observa que tanto en Europa como Norteamérica la clasificación M (mature) es la más vendida. Seguida por E (everyone) y T (teen). En la región de Japón tenemos unknown como la clasificación con más ventas, lo que sugiere que se debe hacer una investigación para completar éstos datos y que nos puedan dar información más completa.
# Lo que sugiere el gráfico junto con el anterior es que los videojuegos de acción con clasificación M son los que más ingresos generan para la empresa.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Muy buen trabajo. Has hecho una comparativa muy acertada entre las 3 regiones. Este tipo de información puede llegar a ser muy valiosa para áreas como la de marketing para esblecer estrategías de distribución y promoción de videojuegos.
# </div>

# %% [markdown]
# ## Pruebas de Hipótesis
#
# Las hipótesis que se busca probar en este proyecto son:
# - [ ] Las calificaciones promedio de los usuarios para las plataformas Xbox One y PC son las mismas.
# - [ ] Las calificaciones promedio de los usuarios para los géneros de Acción y Deportes son diferentes.
#
# Para ambas se redactará una hipotesis nula y una hipótesis alternativa y se elaborará una prueba de hipótesis de una cola, ya que se está comparando la media de dos poblaciones en ambos casos. La redeacción de las hipótesis se elaborará siendo la hipótesis nula que no hay diferencia entre las medias de las poblaciones y la hipótesis alternativa que sí hay una diferencia signigicativa.
#
# Para probar las hipótesis se realizará una prueba estadística de t de student para encontrar si la diferencia entre las medias de las dos poblaciones es significativa. Se establecerá el valor de alpha en 5%.

# %% [markdown]
# ### Primera hipótesis: diferencias en las calificaciones de Xbox ONe y PC
#
# Hipótesis nula: Las calificaciones promedio de los usuarios para las plataformas Xbox One y PC son las mismas.
# Hipótesis alternativa: Las calificaciones promedio de los usuarios para las plataformas Xbox One y PC diferentes.

# %%
df_xbox = recent_games_df[recent_games_df['platform'].str.contains('XOne')]
df_pc = recent_games_df[recent_games_df['platform'].str.contains('PC')]

#eliminar valores nulos en user_score
df_xbox = df_xbox.dropna(subset=['user_score'])
df_pc = df_pc.dropna(subset=['user_score'])

#comprobar diferencia de varianza
var_xbox = df_xbox['user_score'].var()
var_pc = df_pc['user_score'].var()

print(f"Varianza para Xbox One: {var_xbox}")
print(f"Varianza para PC: {var_pc}")
# Out:
# Varianza para Xbox One: 1.9069968429360695
# Varianza para PC: 2.4102204499213022

# %%
alpha = 0.05

results = st.ttest_ind(df_xbox['user_score'] , df_pc['user_score'], equal_var = False)

print('valor p:', results.pvalue)

if ( results.pvalue < alpha) :
    print("Rechazamos la hipótesis nula")
else:
    print("No podemos rechazar la hipótesis nula")
# Out:
# valor p: 0.29856178733970584
# No podemos rechazar la hipótesis nula

# %% [markdown]
# Obtuvimos como resultado que no podemos rechazar la hipótesis nula, por lo que no hay una diferencia significativa entre las calificaciones de los usuarios para los juegos en xbox one y pc.

# %% [markdown]
# ### Segunda hipótesis: diferencias en las calificaciones para Acción y Deportes
#
# Hipótesis nula:Las calificaciones promedio de los usuarios para los géneros de Acción y Deportes son iguales.
# Hipótesis alternativa: Las calificaciones promedio de los usuarios para los géneros de Acción y Deportes son diferentes.

# %%
df_action = recent_games_df[recent_games_df['genre'].str.contains('Action')]
df_sports = recent_games_df[recent_games_df['genre'].str.contains('Sports')]

#eliminar valores ausentes
df_action = df_action.dropna(subset=['user_score'])
df_sports = df_sports.dropna(subset=['user_score'])

#valores de varianza
var_action = df_action['user_score'].var()
var_sports = df_sports['user_score'].var()

print(f"Varianza para action: {var_action}")
print(f"Varianza para sports: {var_sports}")
# Out:
# Varianza para action: 1.845225821564057
# Varianza para sports: 2.883255576441103

# %%
alpha = 0.05

results = st.ttest_ind(df_action['user_score'] , df_sports['user_score'], equal_var = False)

print('valor p:', results.pvalue)

if ( results.pvalue < alpha) :
    print("Rechazamos la hipótesis nula")
else:
    print("No podemos rechazar la hipótesis nula")
# Out:
# valor p: 3.493323839142097e-13
# Rechazamos la hipótesis nula

# %% [markdown]
# Obtuvimos como resultado el rechazo de la hipótesis nula, por lo que podemos decir que hay una diferencia significativa en la calificacion de los usuarios para los géneros de acción y deportes.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Excelente implementación de la metodología de prueba de hipótesis. Sobretodo respecto al manejo de los datos faltantes y la comprobación de las varianzas de los subconjuntos de datos.
#
# </div>

# %% [markdown]
# ## Conclusiones
#
# A lo largo del análisis se encontraron varios insights que pueden ser útiles para formular las estrategias de ventas para el año siguiente. En cuanto a las plataformas, se debe prestar atención a aquellas que han tenido más crecimiento en los últimos años, el análisis de los datos muestra que las siguientes son las plataformas con más crecimiento: PS4, PS3, XBOX ONE, 3DS, WIIU y XBOX360. Sin embargo, hay que poner especial atención en las plataformas nuevas que si siguen las tendencias de las demás plataformas, ganarán popularidad durante los siguientes años, estas son PS4, XBOX ONE y 3DS. De igual forma, el análisis indica que hay plataformas que están en declive, por lo que es probable que las ventas de juegos para ellas sean menores que en años anteriores, especialmente en PS2 Y DS.
#
# Se encontró que no hay una correlación significativa entre las ventas y las reseñas tanto de usuarios como de expertos, por lo que no se recomienda tomarlo como un factor clave para las estrategias de los siguientes años.
#
# Se pudo observar que el género más popular a nivel global es el de acción, siendo también el más popular en las regiones de Europa y Norteamérica. Sin embargo en Japón no es el genero más popular, por lo que se recomienda tomar en cuenta los factores culturales que puedan afectar las preferencias de los usuarios.
#
# Igualmente se observó que los juegos con clasificación M son los que más ventas generan a nivel global, por lo que la empresa puede identificar que sus clientes buscan juegos de ésta clasificación.
#
# Al comprobar las hipótesis se observó que la media de calificación de los usuarios para xbox one y pc no tienen una diferencia significativa, por lo que podría indicar que la calificación no depende de la consola sino del juego. Después se comprobó la diferencia en las medias de calificación de los usuarios para juegos de acción y de deportes, y se obtivo una diferencia significativa. Esto parece indicar que los usuarios se enfocan más en qué tipo de juego y su experiencia en el mismo para dar la calificación, más que en la consola o la interfaz.
#
# Todos estos datos nos dan una buena guía de recomendaciones para las estrategias de ventas y de marketing para el año siguiente. Es importante considerar otros datos que pueden no estar presentes en este análisis, como lo son tamaño del mercado de cada región y diferencias culturales.

# %% [markdown]
# -----

# %% [markdown]
# <div style='background-color:#a9dfbf; padding:15px'>
# <b>Comentario General del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Natalia, has desarrollado un proyecto integrado verdaderamente sobresaliente, demostrando excelencia en el cumplimiento de todos los objetivos establecidos. Tu dominio de las técnicas de manipulación de datos, combinado con un uso experto de herramientas de visualización y una sólida aplicación de pruebas de hipótesis, refleja un nivel de competencia técnica admirable. Lo que realmente distingue tu trabajo es la profundidad y pertinencia de los análisis que has incluido en cada sección del proyecto, una cualidad que enriquece significativamente los hallazgos y demuestra tu capacidad para extraer y comunicar valor de los datos de manera efectiva. Continúa cultivando esta valiosa combinación de habilidades técnicas y analíticas, pues son precisamente estas cualidades las que caracterizan a los analistas de datos más destacados en el campo. Éxitos en tu próximo sprint 🚀
#
# </div>
